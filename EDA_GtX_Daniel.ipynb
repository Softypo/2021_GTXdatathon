# %% [markdown]
# # 1 Setup

# %% [markdown]
# ## 1.1 Import some great packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandas_profiling as pp
#progress bar
from tqdm.notebook import tqdm

# %% [markdown]
# ## Data Exploration

# %%
TemperatureData = pd.read_csv('StructuredData/combined_temperature.csv')
HeaderData = pd.read_csv('StructuredData/consolidated_well_data.csv')
LogData = pd.read_csv('StructuredData/LogData.csv')

# %%
train = pd.read_csv('training.csv')

# %%
train.head()
# Out:
#    Unnamed: 0_x               UWI    BHT  ...  23700.0_GRWS  24000.0_GRWS       Set
# 0             0  100010107020W500  48.33  ...           NaN           NaN  Training
# 1             1  100010608109W500  34.26  ...           NaN           NaN  Training
# 2             3  100011206021W400  29.00  ...           NaN           NaN  Training
# 3             4  100011506915W500  64.00  ...           NaN           NaN  Training
# 4             5  100011804403W500  68.00  ...           NaN           NaN  Training
#
# [5 rows x 331 columns]

# %%
train.columns.tolist()
# Out:
# ['Unnamed: 0_x',
#  'UWI',
#  'BHT',
#  'TrueTemp',
#  'Depth_SS(m)',
#  'Field',
#  'TD (ft)',
#  'Well_Id',
#  'Basin',
#  'TD_0',
#  'TD_1',
#  'TD_2',
#  'TD_3',
#  'TD_4',
#  'TD_5',
#  'TD_6',
#  'TD_7',
#  'TD_8',
#  'TD_9',
#  'TD_10',
#  'TD_11',
#  'TD_12',
#  'KB_0',
#  'KB_1',
#  'KB_2',
#  'KB_3',
#  'KB_4',
#  'KB_5',
#  'KB_6',
#  'KB_7',
#  'KB_8',
#  'KB_9',
#  'KB_10',
#  'KB_11',
#  'KB_12',
#  'Mud Wt_0',
#  'Mud Wt_1',
#  'Mud Wt_2',
#  'Mud Wt_3',
#  'Mud Wt_4',
#  'Mud Wt_5',
#  'Mud Wt_6',
#  'Mud Wt_7',
#  'Mud Wt_8',
#  'Mud Wt_9',
#  'Mud Wt_10',
#  'Mud Wt_11',
#  'Mud Wt_12',
#  'MW@Depth(KB)_0',
#  'MW@Depth(KB)_1',
#  'MW@Depth(KB)_2',
#  'MW@Depth(KB)_3',
#  'MW@Depth(KB)_4',
#  'MW@Depth(KB)_5',
#  'MW@Depth(KB)_6',
#  'MW@Depth(KB)_7',
#  'MW@Depth(KB)_8',
#  'MW@Depth(KB)_9',
#  'MW@Depth(KB)_10',
#  'MW@Depth(KB)_11',
#  'MW@Depth(KB)_12',
#  'Bottom_Hole_Location_X_0',
#  'Bottom_Hole_Location_Y_0',
#  'Elevation(f)_0',
# ...

# %%
#%pprint # to print the list horizonatlly

# %%
['Unnamed: 0_x',  'Unnamed: 0_y', 'Unnamed: 1',
 
 'UWI',  'Well_Id', 'WellName','Field',  'Basin',

 'BHT', 'TrueTemp',

 'Depth_SS(m)', 'TD (ft)',  'td_0', 'TD_0', 'TD_1', 'TD_2', 'TD_3', 'TD_4', 'TD_5', 'TD_6', 'TD_7', 'TD_8', 'TD_9', 'TD_10', 'TD_11', 'TD_12',
 'KB_0', 'KB_1', 'KB_2', 'KB_3', 'KB_4','KB_5', 'KB_6', 'KB_7', 'KB_8', 'KB_9','KB_10', 'KB_11', 'KB_12', 'Elevation_0', 'ElevationDatum_0', 
 'Measured Depth (ft)_0', 'Measured Depth (ft)_1', 'Measured Depth (ft)_2', 'Measured Depth (ft)_3', 'Total Vertical Depth (ft)_0', 'Total Vertical Depth (ft)_1',
 'Total Vertical Depth (ft)_2','Total Vertical Depth (ft)_3', 'Elevation_0.1', 'Elevation_1', 'Elevation_2', 'Elevation_3', 'Elevation(m above sea level)_0',
 'Elevation Meters_0', 'ElevationDatum_0.1', 'TD meters_0', 'Measured Depth (ft)_0.1', 'Total Vertical Depth (ft)_0.1', 'Elevation_0.2', 'Elevation Drill Floor (ft)_0',
 'Elevation Ground (ft)_0', 'Elevation Kelly Bushing (ft)_0',

 'Mud Wt_0', 'Mud Wt_1', 'Mud Wt_2', 'Mud Wt_3', 'Mud Wt_4', 'Mud Wt_5', 'Mud Wt_6', 'Mud Wt_7', 'Mud Wt_8','Mud Wt_9', 'Mud Wt_10', 'Mud Wt_11', 'Mud Wt_12',
 'MW@Depth(KB)_0', 'MW@Depth(KB)_1', 'MW@Depth(KB)_2', 'MW@Depth(KB)_3', 'MW@Depth(KB)_4', 'MW@Depth(KB)_5', 'MW@Depth(KB)_6', 'MW@Depth(KB)_7', 'MW@Depth(KB)_8', 
 'MW@Depth(KB)_9', 'MW@Depth(KB)_10', 'MW@Depth(KB)_11', 'MW@Depth(KB)_12',

 'Bottom_Hole_Location_X_0', 'Bottom_Hole_Location_Y_0', 'Elevation(f)_0', 'Elevation_Reference_0', 'Latitude_0', 'Longitude_0', 'Total_Depth(f)_0', 'X(f)_0', 'Y(f)_0',
  'WGS84Latitude_0', 'WGS84Longitude_0', 'SurfLat_0', 'SurfLong_0', 'SurfaceLatitude_NAD83_0', 'SurfaceLongitude_NAD83_0', 'BottomLatitude_NAD83_0', 'BottomLongitude_NAD83_0',
 'SurfaceLatitude_NAD27_0', 'SurfaceLongitude_NAD27_0', 'BottomLatitude_NAD27_0', 'BottomLongitude_NAD27_0', 'Bottom Hole Location X_m_NAD27_Zone 11N (120 W to 114 W)_0',
 'Bottom Hole Location Y_m_NAD27_Zone 11N (120 W to 114 W)_0', 'SurfaceLatitude_NAD83_0.1', 'SurfaceLongitude_NAD83_0.1', 'BottomLatitude_NAD83_0.1', 'BottomLongitude_NAD83_0.1',
 'SurfaceLatitude_NAD27_0.1', 'SurfaceLongitude_NAD27_0.1', 'BottomLatitude_NAD27_0.1', 'BottomLongitude_NAD27_0.1',

 '01_Wilcox_MD_ft_0', '02_Midway_MD_ft_0', '03_Navarro_MD_ft_0', '04_Taylor_MD_ft_0', '05_Anacacho_MD_ft_0', '06_Austin_Chalk_MD_ft_0', '07_Upper_Eagle_Ford_MD_ft_0', 
 '08_Lower_Eagle_Ford_MD_ft_0', '09_Woodbine_MD_ft_0', '10_Maness_MD_ft_0', '11_Buda_MD_ft_0', '12_Del_Rio_MD_ft_0', '13_Georgetown_MD_ft_0', '14_Edwards_MD_ft_0', '15_Glen_Rose_MD_ft_0',
 '16_Pearsal_MD_ft_0', '17_James_Cow_Creek_MD_ft_0', '18_Sligo_MD_ft_0', '19_Cotton_Valley_MD_ft_0',
 '01_Battle (Surbiton)[SSTVD] (m)_0', '02_Lea_Park (Surbiton)[SSTVD] (m)_0', '03_1st_White_Speckled_Shale (Surbiton)[SSTVD] (m)_0', '04_2nd_White_Speckled_Shale (Surbiton)[SSTVD] (m)_0', 
 '05_Fish_scales (Surbiton)[SSTVD] (m)_0', '06_Mannville_Top (Surbiton)[SSTVD] (m)_0', '07_Ostracod_Beds (Surbiton)[SSTVD] (m)_0', '08_Jurassic_Top (Surbiton)[SSTVD] (m)_0', 
 '09_Montney_Top (Surbiton)[SSTVD] (m)_0', '10_Permian_Top (Surbiton)[SSTVD] (m)_0', '11_Wabamun (Surbiton)[SSTVD] (m)_0', '12_Winterburn (Surbiton)[SSTVD] (m)_0',
 '13_Woodbend (Surbiton)[SSTVD] (m)_0', '14_Duvernay_Top (Surbiton)[SSTVD] (m)_0', '15_Beaverhill (Surbiton)[SSTVD] (m)_0', '16_Elk_Point (Surbiton)[SSTVD] (m)_0', '17_Precambrian Basement (Surbiton)[SSTVD] (m)_0',

 'Spud Date_0', 'Spud Date_1', 'Spud Date_2', 'Spud Date_3', 'Completion Date_0', 'Completion Date_1', 'Completion Date_2','Completion Date_3', 
 'First Production Month_0', 'First Production Month_1', 'First Production Month_2', 'First Production Month_3', 'Plug Date_0', 'Plug Date_1', 'Plug Date_2', 'Plug Date_3',
 'TD Date_0', 'TD Date_1', 'TD Date_2', 'TD Date_3', 'Drilling Days_0', 'Drilling Days_1', 'Drilling Days_2', 'Drilling Days_3', 'Last Production Month_0', 'Last Production Month_1', 
 'Last Production Month_2', 'Last Production Month_3', 'Gas Maximum Date_0', 'Gas Maximum Date_1','Gas Maximum Date_2', 'Gas Maximum Date_3', 'Oil Maximum Date_0', 'Oil Maximum Date_1',
 'Oil Maximum Date_2', 'Oil Maximum Date_3', 'Water Maximum Date_0', 'Water Maximum Date_1', 'Water Maximum Date_2','Water Maximum Date_3', 'Spud Date_0.1',
 'Completion Date_0.1', 'First Production Month_0.1', 'Plug Date_0.1', 'First Production Date_0', 'Last Production Month_0.1',

 'Oil Total Cum (bbl)_0', 'Oil Total Cum (bbl)_1', 'Oil Total Cum (bbl)_2', 'Oil Total Cum (bbl)_3', 'Gas Total Cum (mcf)_0', 'Gas Total Cum (mcf)_1', 'Gas Total Cum (mcf)_2', 
 'Gas Total Cum (mcf)_3', 'Water Total Cum (bbl)_0', 'Water Total Cum (bbl)_1', 'Water Total Cum (bbl)_2', 'Water Total Cum (bbl)_3', 'GOR Total Average_0', 'GOR Total Average_1',
 'GOR Total Average_2', 'GOR Total Average_3','Gas Maximum (mcf)_0', 'Gas Maximum (mcf)_1', 'Gas Maximum (mcf)_2', 'Gas Maximum (mcf)_3',  'Oil Maximum (bbl)_0', 'Oil Maximum (bbl)_1', 'Oil Maximum (bbl)_2', 'Oil Maximum (bbl)_3', 
 'Water Maximum (bbl)_0', 'Water Maximum (bbl)_1', 'Water Maximum (bbl)_2', 'Water Maximum (bbl)_3', 'Liquid Injection Cum (bbl)_0', 'Liquid Injection Cum (bbl)_1', 'Liquid Injection Cum (bbl)_2', 'Liquid Injection Cum (bbl)_3', 'Gas Injection Cum (mcf)_0', 'Gas Injection Cum (mcf)_1',
 'Gas Injection Cum (mcf)_2', 'Gas Injection Cum (mcf)_3', 'Oil Total Cum (bbl)_0.1', 'Gas Total Cum (mcf)_0.1', 'Water Total Cum (bbl)_0.1', 'GOR Total Average_0.1',  'Gas Maximum (mcf)_0.1',
 'Gas Maximum Date_0.1', 'Oil Maximum (bbl)_0.1', 'Oil Maximum Date_0.1', 'Water Maximum (bbl)_0.1', 'Water Maximum Date_0.1', 'Yield Total Average_0',
 
 'LogType', '300.0_GRWS', '600.0_GRWS', '900.0_GRWS','1200.0_GRWS', '1500.0_GRWS', '1800.0_GRWS', '2100.0_GRWS','2400.0_GRWS', '2700.0_GRWS','3000.0_GRWS', '3300.0_GRWS', '3600.0_GRWS',
 '3900.0_GRWS','4200.0_GRWS','4500.0_GRWS', '4800.0_GRWS', '5100.0_GRWS', '5400.0_GRWS', '5700.0_GRWS', '6000.0_GRWS', '6300.0_GRWS','6600.0_GRWS', '6900.0_GRWS', '7200.0_GRWS',
  '7500.0_GRWS', '7800.0_GRWS', '8100.0_GRWS', '8400.0_GRWS','8700.0_GRWS', '9000.0_GRWS','9300.0_GRWS','9600.0_GRWS','9900.0_GRWS', '10200.0_GRWS','10500.0_GRWS', '10800.0_GRWS',
  '11100.0_GRWS', '11400.0_GRWS','11700.0_GRWS','12000.0_GRWS', '12300.0_GRWS', '12600.0_GRWS', '12900.0_GRWS', '13200.0_GRWS','13500.0_GRWS','13800.0_GRWS', '14100.0_GRWS',
 '14400.0_GRWS', '14700.0_GRWS','15000.0_GRWS', '15300.0_GRWS', '15600.0_GRWS', '15900.0_GRWS', '16200.0_GRWS','16500.0_GRWS', '16800.0_GRWS', '17100.0_GRWS','17400.0_GRWS', '17700.0_GRWS',
 '18000.0_GRWS', '18300.0_GRWS', '18600.0_GRWS','18900.0_GRWS','19200.0_GRWS', '19500.0_GRWS', '19800.0_GRWS','20100.0_GRWS', '20400.0_GRWS', '20700.0_GRWS', '21000.0_GRWS',
 '21300.0_GRWS', '21600.0_GRWS', '21900.0_GRWS','22200.0_GRWS','22500.0_GRWS','22800.0_GRWS', '23100.0_GRWS', '23400.0_GRWS','23700.0_GRWS','24000.0_GRWS', 'Set']

# %% [markdown]
# Data Classification
#
# 1. Well Identifier
# 2. Basin/Field Name
# 3. Depths & References
# 4. Temperatures
# 5. Mudweights and Depth References
# 6. Geospatial (Surface and Bottomhole)
# 7. Formation
# 8. Time
# 9. Production
# 10. Well Logs

# %%
# Features Classification

unnamed = ['Unnamed: 0_x',  'Unnamed: 0_y', 'Unnamed: 1']

identifiers = ['UWI', 'Well_Id', 'WellName','Field', 'Basin']

temperature = ['BHT', 'TrueTemp']

depth_ref = ['Depth_SS(m)', 'TD (ft)',  'td_0', 'TD_0', 'TD_1', 'TD_2', 'TD_3', 'TD_4', 'TD_5', 'TD_6', 'TD_7', 'TD_8', 'TD_9', 'TD_10', 'TD_11', 'TD_12',
 'KB_0', 'KB_1', 'KB_2', 'KB_3', 'KB_4','KB_5', 'KB_6', 'KB_7', 'KB_8', 'KB_9','KB_10', 'KB_11', 'KB_12', 'Elevation_0', 'ElevationDatum_0', 
 'Measured Depth (ft)_0', 'Measured Depth (ft)_1', 'Measured Depth (ft)_2', 'Measured Depth (ft)_3', 'Total Vertical Depth (ft)_0', 'Total Vertical Depth (ft)_1',
 'Total Vertical Depth (ft)_2','Total Vertical Depth (ft)_3', 'Elevation_0.1', 'Elevation_1', 'Elevation_2', 'Elevation_3', 'Elevation(m above sea level)_0',
 'Elevation Meters_0', 'ElevationDatum_0.1', 'TD meters_0', 'Measured Depth (ft)_0.1', 'Total Vertical Depth (ft)_0.1', 'Elevation_0.2', 'Elevation Drill Floor (ft)_0',
 'Elevation Ground (ft)_0', 'Elevation Kelly Bushing (ft)_0']

 mud_weight = [ 'Mud Wt_0', 'Mud Wt_1', 'Mud Wt_2', 'Mud Wt_3', 'Mud Wt_4', 'Mud Wt_5', 'Mud Wt_6', 'Mud Wt_7', 'Mud Wt_8','Mud Wt_9', 'Mud Wt_10', 'Mud Wt_11', 'Mud Wt_12',
 'MW@Depth(KB)_0', 'MW@Depth(KB)_1', 'MW@Depth(KB)_2', 'MW@Depth(KB)_3', 'MW@Depth(KB)_4', 'MW@Depth(KB)_5', 'MW@Depth(KB)_6', 'MW@Depth(KB)_7', 'MW@Depth(KB)_8', 
 'MW@Depth(KB)_9', 'MW@Depth(KB)_10', 'MW@Depth(KB)_11', 'MW@Depth(KB)_12']

 geospatial = [ 'Bottom_Hole_Location_X_0', 'Bottom_Hole_Location_Y_0', 'Elevation(f)_0', 'Elevation_Reference_0', 'Latitude_0', 'Longitude_0', 'Total_Depth(f)_0', 'X(f)_0', 'Y(f)_0',
  'WGS84Latitude_0', 'WGS84Longitude_0', 'SurfLat_0', 'SurfLong_0', 'SurfaceLatitude_NAD83_0', 'SurfaceLongitude_NAD83_0', 'BottomLatitude_NAD83_0', 'BottomLongitude_NAD83_0',
 'SurfaceLatitude_NAD27_0', 'SurfaceLongitude_NAD27_0', 'BottomLatitude_NAD27_0', 'BottomLongitude_NAD27_0', 'Bottom Hole Location X_m_NAD27_Zone 11N (120 W to 114 W)_0',
 'Bottom Hole Location Y_m_NAD27_Zone 11N (120 W to 114 W)_0', 'SurfaceLatitude_NAD83_0.1', 'SurfaceLongitude_NAD83_0.1', 'BottomLatitude_NAD83_0.1', 'BottomLongitude_NAD83_0.1',
 'SurfaceLatitude_NAD27_0.1', 'SurfaceLongitude_NAD27_0.1', 'BottomLatitude_NAD27_0.1', 'BottomLongitude_NAD27_0.1']

 formation = [ '01_Wilcox_MD_ft_0', '02_Midway_MD_ft_0', '03_Navarro_MD_ft_0', '04_Taylor_MD_ft_0', '05_Anacacho_MD_ft_0', '06_Austin_Chalk_MD_ft_0', '07_Upper_Eagle_Ford_MD_ft_0', 
 '08_Lower_Eagle_Ford_MD_ft_0', '09_Woodbine_MD_ft_0', '10_Maness_MD_ft_0', '11_Buda_MD_ft_0', '12_Del_Rio_MD_ft_0', '13_Georgetown_MD_ft_0', '14_Edwards_MD_ft_0', '15_Glen_Rose_MD_ft_0',
 '16_Pearsal_MD_ft_0', '17_James_Cow_Creek_MD_ft_0', '18_Sligo_MD_ft_0', '19_Cotton_Valley_MD_ft_0',
 '01_Battle (Surbiton)[SSTVD] (m)_0', '02_Lea_Park (Surbiton)[SSTVD] (m)_0', '03_1st_White_Speckled_Shale (Surbiton)[SSTVD] (m)_0', '04_2nd_White_Speckled_Shale (Surbiton)[SSTVD] (m)_0', 
 '05_Fish_scales (Surbiton)[SSTVD] (m)_0', '06_Mannville_Top (Surbiton)[SSTVD] (m)_0', '07_Ostracod_Beds (Surbiton)[SSTVD] (m)_0', '08_Jurassic_Top (Surbiton)[SSTVD] (m)_0', 
 '09_Montney_Top (Surbiton)[SSTVD] (m)_0', '10_Permian_Top (Surbiton)[SSTVD] (m)_0', '11_Wabamun (Surbiton)[SSTVD] (m)_0', '12_Winterburn (Surbiton)[SSTVD] (m)_0',
 '13_Woodbend (Surbiton)[SSTVD] (m)_0', '14_Duvernay_Top (Surbiton)[SSTVD] (m)_0', '15_Beaverhill (Surbiton)[SSTVD] (m)_0', '16_Elk_Point (Surbiton)[SSTVD] (m)_0', '17_Precambrian Basement (Surbiton)[SSTVD] (m)_0']

 time = ['Spud Date_0', 'Spud Date_1', 'Spud Date_2', 'Spud Date_3', 'Completion Date_0', 'Completion Date_1', 'Completion Date_2','Completion Date_3', 
 'First Production Month_0', 'First Production Month_1', 'First Production Month_2', 'First Production Month_3', 'Plug Date_0', 'Plug Date_1', 'Plug Date_2', 'Plug Date_3',
 'TD Date_0', 'TD Date_1', 'TD Date_2', 'TD Date_3', 'Drilling Days_0', 'Drilling Days_1', 'Drilling Days_2', 'Drilling Days_3', 'Last Production Month_0', 'Last Production Month_1', 
 'Last Production Month_2', 'Last Production Month_3', 'Gas Maximum Date_0', 'Gas Maximum Date_1','Gas Maximum Date_2', 'Gas Maximum Date_3', 'Oil Maximum Date_0', 'Oil Maximum Date_1',
 'Oil Maximum Date_2', 'Oil Maximum Date_3', 'Water Maximum Date_0', 'Water Maximum Date_1', 'Water Maximum Date_2','Water Maximum Date_3', 'Spud Date_0.1',
 'Completion Date_0.1', 'First Production Month_0.1', 'Plug Date_0.1', 'First Production Date_0', 'Last Production Month_0.1']

 fluid_prod = ['Oil Total Cum (bbl)_0', 'Oil Total Cum (bbl)_1', 'Oil Total Cum (bbl)_2', 'Oil Total Cum (bbl)_3', 'Gas Total Cum (mcf)_0', 'Gas Total Cum (mcf)_1', 'Gas Total Cum (mcf)_2', 
 'Gas Total Cum (mcf)_3', 'Water Total Cum (bbl)_0', 'Water Total Cum (bbl)_1', 'Water Total Cum (bbl)_2', 'Water Total Cum (bbl)_3', 'GOR Total Average_0', 'GOR Total Average_1',
 'GOR Total Average_2', 'GOR Total Average_3','Gas Maximum (mcf)_0', 'Gas Maximum (mcf)_1', 'Gas Maximum (mcf)_2', 'Gas Maximum (mcf)_3',  'Oil Maximum (bbl)_0', 'Oil Maximum (bbl)_1', 'Oil Maximum (bbl)_2', 'Oil Maximum (bbl)_3', 
 'Water Maximum (bbl)_0', 'Water Maximum (bbl)_1', 'Water Maximum (bbl)_2', 'Water Maximum (bbl)_3', 'Liquid Injection Cum (bbl)_0', 'Liquid Injection Cum (bbl)_1', 'Liquid Injection Cum (bbl)_2', 'Liquid Injection Cum (bbl)_3', 'Gas Injection Cum (mcf)_0', 'Gas Injection Cum (mcf)_1',
 'Gas Injection Cum (mcf)_2', 'Gas Injection Cum (mcf)_3', 'Oil Total Cum (bbl)_0.1', 'Gas Total Cum (mcf)_0.1', 'Water Total Cum (bbl)_0.1', 'GOR Total Average_0.1',  'Gas Maximum (mcf)_0.1',
 'Gas Maximum Date_0.1', 'Oil Maximum (bbl)_0.1', 'Oil Maximum Date_0.1', 'Water Maximum (bbl)_0.1', 'Water Maximum Date_0.1', 'Yield Total Average_0']

well_log = ['LogType', '300.0_GRWS', '600.0_GRWS', '900.0_GRWS','1200.0_GRWS', '1500.0_GRWS', '1800.0_GRWS', '2100.0_GRWS','2400.0_GRWS', '2700.0_GRWS','3000.0_GRWS', '3300.0_GRWS', '3600.0_GRWS',
 '3900.0_GRWS','4200.0_GRWS','4500.0_GRWS', '4800.0_GRWS', '5100.0_GRWS', '5400.0_GRWS', '5700.0_GRWS', '6000.0_GRWS', '6300.0_GRWS','6600.0_GRWS', '6900.0_GRWS', '7200.0_GRWS',
  '7500.0_GRWS', '7800.0_GRWS', '8100.0_GRWS', '8400.0_GRWS','8700.0_GRWS', '9000.0_GRWS','9300.0_GRWS','9600.0_GRWS','9900.0_GRWS', '10200.0_GRWS','10500.0_GRWS', '10800.0_GRWS',
  '11100.0_GRWS', '11400.0_GRWS','11700.0_GRWS','12000.0_GRWS', '12300.0_GRWS', '12600.0_GRWS', '12900.0_GRWS', '13200.0_GRWS','13500.0_GRWS','13800.0_GRWS', '14100.0_GRWS',
 '14400.0_GRWS', '14700.0_GRWS','15000.0_GRWS', '15300.0_GRWS', '15600.0_GRWS', '15900.0_GRWS', '16200.0_GRWS','16500.0_GRWS', '16800.0_GRWS', '17100.0_GRWS','17400.0_GRWS', '17700.0_GRWS',
 '18000.0_GRWS', '18300.0_GRWS', '18600.0_GRWS','18900.0_GRWS','19200.0_GRWS', '19500.0_GRWS', '19800.0_GRWS','20100.0_GRWS', '20400.0_GRWS', '20700.0_GRWS', '21000.0_GRWS',
 '21300.0_GRWS', '21600.0_GRWS', '21900.0_GRWS','22200.0_GRWS','22500.0_GRWS','22800.0_GRWS', '23100.0_GRWS', '23400.0_GRWS','23700.0_GRWS','24000.0_GRWS', 'Set']

# %% [markdown]
# ### Feature Selection

# %%
# Unnamed Features
train_un = train[['Unnamed: 0_x',  'Unnamed: 0_y', 'Unnamed: 1']]
train_un
# Out:
#      Unnamed: 0_x  Unnamed: 0_y  Unnamed: 1
# 0               0           NaN         NaN
# 1               1           NaN         NaN
# 2               3           NaN         NaN
# 3               4           NaN         NaN
# 4               5           NaN         NaN
# ..            ...           ...         ...
# 610           317           NaN         NaN
# 611           318           NaN         NaN
# 612           320           NaN         NaN
# 613           322           NaN         NaN
# 614           323         321.0         0.0
#
# [615 rows x 3 columns]

# %%
# identifier features
train_id = train[['UWI', 'Well_Id', 'WellName','Field', 'Basin']]
train_id
# Out:
#                   UWI           Well_Id      WellName      Field Basin
# 0    100010107020W500  100010107020W500           NaN   Duvernay    DV
# 1    100010608109W500  100010608109W500           NaN   Duvernay    DV
# 2    100011206021W400  100011206021W400           NaN   Duvernay    DV
# 3    100011506915W500  100011506915W500           NaN   Duvernay    DV
# 4    100011804403W500  100011804403W500           NaN   Duvernay    DV
# ..                ...               ...           ...        ...   ...
# 610    42493318190000    42493318190000           NaN  Eaglebine    EB
# 611    42493319370000    42493319370000           NaN  Eaglebine    EB
# 612    42507007550000    42507007550000           NaN  Eaglebine    EB
# 613    42507312960000    42507312960000           NaN  Eaglebine    EB
# 614    42507326870000    42507326870000  4.250733e+13  Eaglebine    EB
#
# [615 rows x 5 columns]

# %%
# temperature features
train_temp = train[['BHT', 'TrueTemp']]
train_temp
# Out:
#            BHT    TrueTemp
# 0    48.330000   60.970000
# 1    34.260000   63.980000
# 2    29.000000   39.070000
# 3    64.000000   69.470000
# 4    68.000000   75.230000
# ..         ...         ...
# 610  76.666667   96.105556
# 611  78.888889  100.472222
# 612  65.555556   78.161111
# 613  67.222222   94.794444
# 614  50.000000   78.888889
#
# [615 rows x 2 columns]

# %%
# depth reference features

train_depth_ref = train[['Depth_SS(m)', 'TD (ft)',  'td_0', 'TD_0', 'TD_1', 'TD_2', 'TD_3', 'TD_4', 'TD_5', 'TD_6', 'TD_7', 'TD_8', 'TD_9', 'TD_10', 'TD_11', 'TD_12',
 'KB_0', 'KB_1', 'KB_2', 'KB_3', 'KB_4','KB_5', 'KB_6', 'KB_7', 'KB_8', 'KB_9','KB_10', 'KB_11', 'KB_12', 'Elevation_0', 'ElevationDatum_0', 
 'Measured Depth (ft)_0', 'Measured Depth (ft)_1', 'Measured Depth (ft)_2', 'Measured Depth (ft)_3', 'Total Vertical Depth (ft)_0', 'Total Vertical Depth (ft)_1',
 'Total Vertical Depth (ft)_2','Total Vertical Depth (ft)_3', 'Elevation_0.1', 'Elevation_1', 'Elevation_2', 'Elevation_3', 'Elevation(m above sea level)_0',
 'Elevation Meters_0', 'ElevationDatum_0.1', 'TD meters_0', 'Measured Depth (ft)_0.1', 'Total Vertical Depth (ft)_0.1', 'Elevation_0.2', 'Elevation Drill Floor (ft)_0',
 'Elevation Ground (ft)_0', 'Elevation Kelly Bushing (ft)_0']
]

train_depth_ref
# Out:
#      Depth_SS(m)  ...  Elevation Kelly Bushing (ft)_0
# 0          716.0  ...                          2300.0
# 1         1044.4  ...                          2119.0
# 2          171.9  ...                          2139.0
# 3          936.4  ...                          2864.0
# 4         1065.6  ...                          3107.0
# ..           ...  ...                             ...
# 610          NaN  ...                             NaN
# 611          NaN  ...                             NaN
# 612          NaN  ...                             NaN
# 613          NaN  ...                             NaN
# 614          NaN  ...                             NaN
#
# [615 rows x 53 columns]

# %%
# mud Weight features
train_mud_weight = train[['Mud Wt_0', 'Mud Wt_1', 'Mud Wt_2', 'Mud Wt_3', 'Mud Wt_4', 'Mud Wt_5', 'Mud Wt_6', 'Mud Wt_7', 'Mud Wt_8','Mud Wt_9', 'Mud Wt_10', 'Mud Wt_11', 'Mud Wt_12', 'MW@Depth(KB)_0', 'MW@Depth(KB)_1', 'MW@Depth(KB)_2', 'MW@Depth(KB)_3', 'MW@Depth(KB)_4', 'MW@Depth(KB)_5', 'MW@Depth(KB)_6', 'MW@Depth(KB)_7', 'MW@Depth(KB)_8','MW@Depth(KB)_9', 'MW@Depth(KB)_10', 'MW@Depth(KB)_11', 'MW@Depth(KB)_12']]
train_mud_weight
# Out:
#      Mud Wt_0  Mud Wt_1  ...  MW@Depth(KB)_11  MW@Depth(KB)_12
# 0         NaN       NaN  ...              NaN              NaN
# 1         NaN       NaN  ...              NaN              NaN
# 2         NaN       NaN  ...              NaN              NaN
# 3         NaN       NaN  ...              NaN              NaN
# 4         NaN       NaN  ...              NaN              NaN
# ..        ...       ...  ...              ...              ...
# 610       9.8       NaN  ...              NaN              NaN
# 611       9.4       NaN  ...              NaN              NaN
# 612       9.7       9.0  ...              NaN              NaN
# 613       9.3       NaN  ...              NaN              NaN
# 614      10.3       NaN  ...              NaN              NaN
#
# [615 rows x 26 columns]

# %%
# geospatial features

train_geospatial = train[[ 'Bottom_Hole_Location_X_0', 'Bottom_Hole_Location_Y_0', 'Elevation(f)_0', 'Elevation_Reference_0', 'Latitude_0', 'Longitude_0', 'Total_Depth(f)_0', 'X(f)_0', 'Y(f)_0',
  'WGS84Latitude_0', 'WGS84Longitude_0', 'SurfLat_0', 'SurfLong_0', 'SurfaceLatitude_NAD83_0', 'SurfaceLongitude_NAD83_0', 'BottomLatitude_NAD83_0', 'BottomLongitude_NAD83_0',
 'SurfaceLatitude_NAD27_0', 'SurfaceLongitude_NAD27_0', 'BottomLatitude_NAD27_0', 'BottomLongitude_NAD27_0', 'Bottom Hole Location X_m_NAD27_Zone 11N (120 W to 114 W)_0',
 'Bottom Hole Location Y_m_NAD27_Zone 11N (120 W to 114 W)_0', 'SurfaceLatitude_NAD83_0.1', 'SurfaceLongitude_NAD83_0.1', 'BottomLatitude_NAD83_0.1', 'BottomLongitude_NAD83_0.1',
 'SurfaceLatitude_NAD27_0.1', 'SurfaceLongitude_NAD27_0.1', 'BottomLatitude_NAD27_0.1', 'BottomLongitude_NAD27_0.1']]

train_geospatial
# Out:
#      Bottom_Hole_Location_X_0  ...  BottomLongitude_NAD27_0.1
# 0                         NaN  ...                -116.903553
# 1                         NaN  ...                -115.390554
# 2                         NaN  ...                -113.002616
# 3                         NaN  ...                -116.188158
# 4                         NaN  ...                -114.415621
# ..                        ...  ...                        ...
# 610                2283567.03  ...                        NaN
# 611                2263416.19  ...                        NaN
# 612                1819839.32  ...                        NaN
# 613                1678556.34  ...                        NaN
# 614                1812507.42  ...                        NaN
#
# [615 rows x 31 columns]

# %%
# formation features

train_formation = train[['01_Wilcox_MD_ft_0', '02_Midway_MD_ft_0', '03_Navarro_MD_ft_0', '04_Taylor_MD_ft_0', '05_Anacacho_MD_ft_0', '06_Austin_Chalk_MD_ft_0', '07_Upper_Eagle_Ford_MD_ft_0', 
 '08_Lower_Eagle_Ford_MD_ft_0', '09_Woodbine_MD_ft_0', '10_Maness_MD_ft_0', '11_Buda_MD_ft_0', '12_Del_Rio_MD_ft_0', '13_Georgetown_MD_ft_0', '14_Edwards_MD_ft_0', '15_Glen_Rose_MD_ft_0',
 '16_Pearsal_MD_ft_0', '17_James_Cow_Creek_MD_ft_0', '18_Sligo_MD_ft_0', '19_Cotton_Valley_MD_ft_0',
 '01_Battle (Surbiton)[SSTVD] (m)_0', '02_Lea_Park (Surbiton)[SSTVD] (m)_0', '03_1st_White_Speckled_Shale (Surbiton)[SSTVD] (m)_0', '04_2nd_White_Speckled_Shale (Surbiton)[SSTVD] (m)_0', 
 '05_Fish_scales (Surbiton)[SSTVD] (m)_0', '06_Mannville_Top (Surbiton)[SSTVD] (m)_0', '07_Ostracod_Beds (Surbiton)[SSTVD] (m)_0', '08_Jurassic_Top (Surbiton)[SSTVD] (m)_0', 
 '09_Montney_Top (Surbiton)[SSTVD] (m)_0', '10_Permian_Top (Surbiton)[SSTVD] (m)_0', '11_Wabamun (Surbiton)[SSTVD] (m)_0', '12_Winterburn (Surbiton)[SSTVD] (m)_0',
 '13_Woodbend (Surbiton)[SSTVD] (m)_0', '14_Duvernay_Top (Surbiton)[SSTVD] (m)_0', '15_Beaverhill (Surbiton)[SSTVD] (m)_0', '16_Elk_Point (Surbiton)[SSTVD] (m)_0', '17_Precambrian Basement (Surbiton)[SSTVD] (m)_0']]

train_formation
# Out:
#      01_Wilcox_MD_ft_0  ...  17_Precambrian Basement (Surbiton)[SSTVD] (m)_0
# 0                  NaN  ...                                              NaN
# 1                  NaN  ...                                          -1078.4
# 2                  NaN  ...                                              NaN
# 3                  NaN  ...                                              NaN
# 4                  NaN  ...                                              NaN
# ..                 ...  ...                                              ...
# 610                0.0  ...                                              NaN
# 611                0.0  ...                                              NaN
# 612                0.0  ...                                              NaN
# 613                0.0  ...                                              NaN
# 614                0.0  ...                                              NaN
#
# [615 rows x 36 columns]

# %%
# time features

train_time = train[['Spud Date_0', 'Spud Date_1', 'Spud Date_2', 'Spud Date_3', 'Completion Date_0', 'Completion Date_1', 'Completion Date_2','Completion Date_3', 
 'First Production Month_0', 'First Production Month_1', 'First Production Month_2', 'First Production Month_3', 'Plug Date_0', 'Plug Date_1', 'Plug Date_2', 'Plug Date_3',
 'TD Date_0', 'TD Date_1', 'TD Date_2', 'TD Date_3', 'Drilling Days_0', 'Drilling Days_1', 'Drilling Days_2', 'Drilling Days_3', 'Last Production Month_0', 'Last Production Month_1', 
 'Last Production Month_2', 'Last Production Month_3', 'Gas Maximum Date_0', 'Gas Maximum Date_1','Gas Maximum Date_2', 'Gas Maximum Date_3', 'Oil Maximum Date_0', 'Oil Maximum Date_1',
 'Oil Maximum Date_2', 'Oil Maximum Date_3', 'Water Maximum Date_0', 'Water Maximum Date_1', 'Water Maximum Date_2','Water Maximum Date_3', 'Spud Date_0.1',
 'Completion Date_0.1', 'First Production Month_0.1', 'Plug Date_0.1', 'First Production Date_0', 'Last Production Month_0.1']]

train_time
# Out:
#     Spud Date_0 Spud Date_1  ... First Production Date_0 Last Production Month_0.1
# 0           NaN         NaN  ...                     NaN                       NaN
# 1           NaN         NaN  ...              1992-05-22                1992-08-01
# 2           NaN         NaN  ...                     NaN                       NaN
# 3           NaN         NaN  ...                     NaN                       NaN
# 4           NaN         NaN  ...                     NaN                       NaN
# ..          ...         ...  ...                     ...                       ...
# 610  1985-11-26         NaN  ...                     NaN                       NaN
# 611         NaN         NaN  ...                     NaN                       NaN
# 612         NaN         NaN  ...                     NaN                       NaN
# 613         NaN         NaN  ...                     NaN                       NaN
# ...

# %%
# fluid production features

train_prod = train[['Oil Total Cum (bbl)_0', 'Oil Total Cum (bbl)_1', 'Oil Total Cum (bbl)_2', 'Oil Total Cum (bbl)_3', 'Gas Total Cum (mcf)_0', 'Gas Total Cum (mcf)_1', 'Gas Total Cum (mcf)_2', 
 'Gas Total Cum (mcf)_3', 'Water Total Cum (bbl)_0', 'Water Total Cum (bbl)_1', 'Water Total Cum (bbl)_2', 'Water Total Cum (bbl)_3', 'GOR Total Average_0', 'GOR Total Average_1',
 'GOR Total Average_2', 'GOR Total Average_3','Gas Maximum (mcf)_0', 'Gas Maximum (mcf)_1', 'Gas Maximum (mcf)_2', 'Gas Maximum (mcf)_3',  'Oil Maximum (bbl)_0', 'Oil Maximum (bbl)_1', 'Oil Maximum (bbl)_2', 'Oil Maximum (bbl)_3', 
 'Water Maximum (bbl)_0', 'Water Maximum (bbl)_1', 'Water Maximum (bbl)_2', 'Water Maximum (bbl)_3', 'Liquid Injection Cum (bbl)_0', 'Liquid Injection Cum (bbl)_1', 'Liquid Injection Cum (bbl)_2', 'Liquid Injection Cum (bbl)_3', 'Gas Injection Cum (mcf)_0', 'Gas Injection Cum (mcf)_1',
 'Gas Injection Cum (mcf)_2', 'Gas Injection Cum (mcf)_3', 'Oil Total Cum (bbl)_0.1', 'Gas Total Cum (mcf)_0.1', 'Water Total Cum (bbl)_0.1', 'GOR Total Average_0.1',  'Gas Maximum (mcf)_0.1',
 'Gas Maximum Date_0.1', 'Oil Maximum (bbl)_0.1', 'Oil Maximum Date_0.1', 'Water Maximum (bbl)_0.1', 'Water Maximum Date_0.1', 'Yield Total Average_0']]

train_prod
# Out:
#      Oil Total Cum (bbl)_0  ...  Yield Total Average_0
# 0                      NaN  ...                    NaN
# 1                      NaN  ...               1256.918
# 2                      NaN  ...                    NaN
# 3                      NaN  ...                    NaN
# 4                      NaN  ...                    NaN
# ..                     ...  ...                    ...
# 610                463.000  ...                    NaN
# 611              29479.885  ...                    NaN
# 612                    NaN  ...                    NaN
# 613                    NaN  ...                    NaN
# 614                    NaN  ...                    NaN
#
# [615 rows x 47 columns]

# %%
# well logs features: GR

train_well_log = train[['LogType', '300.0_GRWS', '600.0_GRWS', '900.0_GRWS','1200.0_GRWS', '1500.0_GRWS', '1800.0_GRWS', '2100.0_GRWS','2400.0_GRWS', '2700.0_GRWS','3000.0_GRWS', '3300.0_GRWS', '3600.0_GRWS',
 '3900.0_GRWS','4200.0_GRWS','4500.0_GRWS', '4800.0_GRWS', '5100.0_GRWS', '5400.0_GRWS', '5700.0_GRWS', '6000.0_GRWS', '6300.0_GRWS','6600.0_GRWS', '6900.0_GRWS', '7200.0_GRWS',
  '7500.0_GRWS', '7800.0_GRWS', '8100.0_GRWS', '8400.0_GRWS','8700.0_GRWS', '9000.0_GRWS','9300.0_GRWS','9600.0_GRWS','9900.0_GRWS', '10200.0_GRWS','10500.0_GRWS', '10800.0_GRWS',
  '11100.0_GRWS', '11400.0_GRWS','11700.0_GRWS','12000.0_GRWS', '12300.0_GRWS', '12600.0_GRWS', '12900.0_GRWS', '13200.0_GRWS','13500.0_GRWS','13800.0_GRWS', '14100.0_GRWS',
 '14400.0_GRWS', '14700.0_GRWS','15000.0_GRWS', '15300.0_GRWS', '15600.0_GRWS', '15900.0_GRWS', '16200.0_GRWS','16500.0_GRWS', '16800.0_GRWS', '17100.0_GRWS','17400.0_GRWS', '17700.0_GRWS',
 '18000.0_GRWS', '18300.0_GRWS', '18600.0_GRWS','18900.0_GRWS','19200.0_GRWS', '19500.0_GRWS', '19800.0_GRWS','20100.0_GRWS', '20400.0_GRWS', '20700.0_GRWS', '21000.0_GRWS',
 '21300.0_GRWS', '21600.0_GRWS', '21900.0_GRWS','22200.0_GRWS','22500.0_GRWS','22800.0_GRWS', '23100.0_GRWS', '23400.0_GRWS','23700.0_GRWS','24000.0_GRWS', 'Set']]

train_well_log
# Out:
#      LogType  300.0_GRWS  600.0_GRWS  ...  23700.0_GRWS  24000.0_GRWS       Set
# 0        NaN         NaN         NaN  ...           NaN           NaN  Training
# 1        NaN         NaN         NaN  ...           NaN           NaN  Training
# 2        NaN         NaN         NaN  ...           NaN           NaN  Training
# 3        NaN         NaN         NaN  ...           NaN           NaN  Training
# 4        NaN         NaN         NaN  ...           NaN           NaN  Training
# ..       ...         ...         ...  ...           ...           ...       ...
# 610      NaN         NaN         NaN  ...           NaN           NaN  Training
# 611      NaN         NaN         NaN  ...           NaN           NaN  Training
# 612      NaN         NaN         NaN  ...           NaN           NaN  Training
# 613      NaN         NaN         NaN  ...           NaN           NaN  Training
# 614  Cleaned         NaN         NaN  ...           NaN           NaN  Training
#
# ...

# %%
# create new train dataframe from the re-ordered lists of features

train = train[['Unnamed: 0_x',  'Unnamed: 0_y', 'Unnamed: 1',
 
 'UWI',  'Well_Id', 'WellName','Field',  'Basin',

 'BHT', 'TrueTemp',

 'Depth_SS(m)', 'TD (ft)',  'td_0', 'TD_0', 'TD_1', 'TD_2', 'TD_3', 'TD_4', 'TD_5', 'TD_6', 'TD_7', 'TD_8', 'TD_9', 'TD_10', 'TD_11', 'TD_12',
 'KB_0', 'KB_1', 'KB_2', 'KB_3', 'KB_4','KB_5', 'KB_6', 'KB_7', 'KB_8', 'KB_9','KB_10', 'KB_11', 'KB_12', 'Elevation_0', 'ElevationDatum_0', 
 'Measured Depth (ft)_0', 'Measured Depth (ft)_1', 'Measured Depth (ft)_2', 'Measured Depth (ft)_3', 'Total Vertical Depth (ft)_0', 'Total Vertical Depth (ft)_1',
 'Total Vertical Depth (ft)_2','Total Vertical Depth (ft)_3', 'Elevation_0.1', 'Elevation_1', 'Elevation_2', 'Elevation_3', 'Elevation(m above sea level)_0',
 'Elevation Meters_0', 'ElevationDatum_0.1', 'TD meters_0', 'Measured Depth (ft)_0.1', 'Total Vertical Depth (ft)_0.1', 'Elevation_0.2', 'Elevation Drill Floor (ft)_0',
 'Elevation Ground (ft)_0', 'Elevation Kelly Bushing (ft)_0',

 'Mud Wt_0', 'Mud Wt_1', 'Mud Wt_2', 'Mud Wt_3', 'Mud Wt_4', 'Mud Wt_5', 'Mud Wt_6', 'Mud Wt_7', 'Mud Wt_8','Mud Wt_9', 'Mud Wt_10', 'Mud Wt_11', 'Mud Wt_12',
 'MW@Depth(KB)_0', 'MW@Depth(KB)_1', 'MW@Depth(KB)_2', 'MW@Depth(KB)_3', 'MW@Depth(KB)_4', 'MW@Depth(KB)_5', 'MW@Depth(KB)_6', 'MW@Depth(KB)_7', 'MW@Depth(KB)_8', 
 'MW@Depth(KB)_9', 'MW@Depth(KB)_10', 'MW@Depth(KB)_11', 'MW@Depth(KB)_12',

 'Bottom_Hole_Location_X_0', 'Bottom_Hole_Location_Y_0', 'Elevation(f)_0', 'Elevation_Reference_0', 'Latitude_0', 'Longitude_0', 'Total_Depth(f)_0', 'X(f)_0', 'Y(f)_0',
  'WGS84Latitude_0', 'WGS84Longitude_0', 'SurfLat_0', 'SurfLong_0', 'SurfaceLatitude_NAD83_0', 'SurfaceLongitude_NAD83_0', 'BottomLatitude_NAD83_0', 'BottomLongitude_NAD83_0',
 'SurfaceLatitude_NAD27_0', 'SurfaceLongitude_NAD27_0', 'BottomLatitude_NAD27_0', 'BottomLongitude_NAD27_0', 'Bottom Hole Location X_m_NAD27_Zone 11N (120 W to 114 W)_0',
 'Bottom Hole Location Y_m_NAD27_Zone 11N (120 W to 114 W)_0', 'SurfaceLatitude_NAD83_0.1', 'SurfaceLongitude_NAD83_0.1', 'BottomLatitude_NAD83_0.1', 'BottomLongitude_NAD83_0.1',
 'SurfaceLatitude_NAD27_0.1', 'SurfaceLongitude_NAD27_0.1', 'BottomLatitude_NAD27_0.1', 'BottomLongitude_NAD27_0.1',

 '01_Wilcox_MD_ft_0', '02_Midway_MD_ft_0', '03_Navarro_MD_ft_0', '04_Taylor_MD_ft_0', '05_Anacacho_MD_ft_0', '06_Austin_Chalk_MD_ft_0', '07_Upper_Eagle_Ford_MD_ft_0', 
 '08_Lower_Eagle_Ford_MD_ft_0', '09_Woodbine_MD_ft_0', '10_Maness_MD_ft_0', '11_Buda_MD_ft_0', '12_Del_Rio_MD_ft_0', '13_Georgetown_MD_ft_0', '14_Edwards_MD_ft_0', '15_Glen_Rose_MD_ft_0',
 '16_Pearsal_MD_ft_0', '17_James_Cow_Creek_MD_ft_0', '18_Sligo_MD_ft_0', '19_Cotton_Valley_MD_ft_0',
 '01_Battle (Surbiton)[SSTVD] (m)_0', '02_Lea_Park (Surbiton)[SSTVD] (m)_0', '03_1st_White_Speckled_Shale (Surbiton)[SSTVD] (m)_0', '04_2nd_White_Speckled_Shale (Surbiton)[SSTVD] (m)_0', 
 '05_Fish_scales (Surbiton)[SSTVD] (m)_0', '06_Mannville_Top (Surbiton)[SSTVD] (m)_0', '07_Ostracod_Beds (Surbiton)[SSTVD] (m)_0', '08_Jurassic_Top (Surbiton)[SSTVD] (m)_0', 
 '09_Montney_Top (Surbiton)[SSTVD] (m)_0', '10_Permian_Top (Surbiton)[SSTVD] (m)_0', '11_Wabamun (Surbiton)[SSTVD] (m)_0', '12_Winterburn (Surbiton)[SSTVD] (m)_0',
 '13_Woodbend (Surbiton)[SSTVD] (m)_0', '14_Duvernay_Top (Surbiton)[SSTVD] (m)_0', '15_Beaverhill (Surbiton)[SSTVD] (m)_0', '16_Elk_Point (Surbiton)[SSTVD] (m)_0', '17_Precambrian Basement (Surbiton)[SSTVD] (m)_0',

 'Spud Date_0', 'Spud Date_1', 'Spud Date_2', 'Spud Date_3', 'Completion Date_0', 'Completion Date_1', 'Completion Date_2','Completion Date_3', 
 'First Production Month_0', 'First Production Month_1', 'First Production Month_2', 'First Production Month_3', 'Plug Date_0', 'Plug Date_1', 'Plug Date_2', 'Plug Date_3',
 'TD Date_0', 'TD Date_1', 'TD Date_2', 'TD Date_3', 'Drilling Days_0', 'Drilling Days_1', 'Drilling Days_2', 'Drilling Days_3', 'Last Production Month_0', 'Last Production Month_1', 
 'Last Production Month_2', 'Last Production Month_3', 'Gas Maximum Date_0', 'Gas Maximum Date_1','Gas Maximum Date_2', 'Gas Maximum Date_3', 'Oil Maximum Date_0', 'Oil Maximum Date_1',
 'Oil Maximum Date_2', 'Oil Maximum Date_3', 'Water Maximum Date_0', 'Water Maximum Date_1', 'Water Maximum Date_2','Water Maximum Date_3', 'Spud Date_0.1',
 'Completion Date_0.1', 'First Production Month_0.1', 'Plug Date_0.1', 'First Production Date_0', 'Last Production Month_0.1',

 'Oil Total Cum (bbl)_0', 'Oil Total Cum (bbl)_1', 'Oil Total Cum (bbl)_2', 'Oil Total Cum (bbl)_3', 'Gas Total Cum (mcf)_0', 'Gas Total Cum (mcf)_1', 'Gas Total Cum (mcf)_2', 
 'Gas Total Cum (mcf)_3', 'Water Total Cum (bbl)_0', 'Water Total Cum (bbl)_1', 'Water Total Cum (bbl)_2', 'Water Total Cum (bbl)_3', 'GOR Total Average_0', 'GOR Total Average_1',
 'GOR Total Average_2', 'GOR Total Average_3','Gas Maximum (mcf)_0', 'Gas Maximum (mcf)_1', 'Gas Maximum (mcf)_2', 'Gas Maximum (mcf)_3',  'Oil Maximum (bbl)_0', 'Oil Maximum (bbl)_1', 'Oil Maximum (bbl)_2', 'Oil Maximum (bbl)_3', 
 'Water Maximum (bbl)_0', 'Water Maximum (bbl)_1', 'Water Maximum (bbl)_2', 'Water Maximum (bbl)_3', 'Liquid Injection Cum (bbl)_0', 'Liquid Injection Cum (bbl)_1', 'Liquid Injection Cum (bbl)_2', 'Liquid Injection Cum (bbl)_3', 'Gas Injection Cum (mcf)_0', 'Gas Injection Cum (mcf)_1',
 'Gas Injection Cum (mcf)_2', 'Gas Injection Cum (mcf)_3', 'Oil Total Cum (bbl)_0.1', 'Gas Total Cum (mcf)_0.1', 'Water Total Cum (bbl)_0.1', 'GOR Total Average_0.1',  'Gas Maximum (mcf)_0.1',
 'Gas Maximum Date_0.1', 'Oil Maximum (bbl)_0.1', 'Oil Maximum Date_0.1', 'Water Maximum (bbl)_0.1', 'Water Maximum Date_0.1', 'Yield Total Average_0',
 
 'LogType', '300.0_GRWS', '600.0_GRWS', '900.0_GRWS','1200.0_GRWS', '1500.0_GRWS', '1800.0_GRWS', '2100.0_GRWS','2400.0_GRWS', '2700.0_GRWS','3000.0_GRWS', '3300.0_GRWS', '3600.0_GRWS',
 '3900.0_GRWS','4200.0_GRWS','4500.0_GRWS', '4800.0_GRWS', '5100.0_GRWS', '5400.0_GRWS', '5700.0_GRWS', '6000.0_GRWS', '6300.0_GRWS','6600.0_GRWS', '6900.0_GRWS', '7200.0_GRWS',
  '7500.0_GRWS', '7800.0_GRWS', '8100.0_GRWS', '8400.0_GRWS','8700.0_GRWS', '9000.0_GRWS','9300.0_GRWS','9600.0_GRWS','9900.0_GRWS', '10200.0_GRWS','10500.0_GRWS', '10800.0_GRWS',
  '11100.0_GRWS', '11400.0_GRWS','11700.0_GRWS','12000.0_GRWS', '12300.0_GRWS', '12600.0_GRWS', '12900.0_GRWS', '13200.0_GRWS','13500.0_GRWS','13800.0_GRWS', '14100.0_GRWS',
 '14400.0_GRWS', '14700.0_GRWS','15000.0_GRWS', '15300.0_GRWS', '15600.0_GRWS', '15900.0_GRWS', '16200.0_GRWS','16500.0_GRWS', '16800.0_GRWS', '17100.0_GRWS','17400.0_GRWS', '17700.0_GRWS',
 '18000.0_GRWS', '18300.0_GRWS', '18600.0_GRWS','18900.0_GRWS','19200.0_GRWS', '19500.0_GRWS', '19800.0_GRWS','20100.0_GRWS', '20400.0_GRWS', '20700.0_GRWS', '21000.0_GRWS',
 '21300.0_GRWS', '21600.0_GRWS', '21900.0_GRWS','22200.0_GRWS','22500.0_GRWS','22800.0_GRWS', '23100.0_GRWS', '23400.0_GRWS','23700.0_GRWS','24000.0_GRWS', 'Set']]

# %%
train.head()
# Out:
#    Unnamed: 0_x  Unnamed: 0_y  Unnamed: 1  ... 23700.0_GRWS 24000.0_GRWS       Set
# 0             0           NaN         NaN  ...          NaN          NaN  Training
# 1             1           NaN         NaN  ...          NaN          NaN  Training
# 2             3           NaN         NaN  ...          NaN          NaN  Training
# 3             4           NaN         NaN  ...          NaN          NaN  Training
# 4             5           NaN         NaN  ...          NaN          NaN  Training
#
# [5 rows x 331 columns]
