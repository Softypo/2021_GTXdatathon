# %% [markdown]
# # 1 Setup

# %% [markdown]
# ## 1.1 Import some great packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
#progress bar
from tqdm.notebook import tqdm

# %% [markdown]
# ## 1.2 Load the data from organizer Google drive

# %%
def folder_download(folder_id):
  # authenticate
  from google.colab import auth
  auth.authenticate_user()
  # get folder_name
  from googleapiclient.discovery import build
  service = build('drive', 'v3')
  folder_name = service.files().get(fileId=folder_id).execute()['name']
  # import library and download
  # !wget -qnc https://github.com/segnolin/google-drive-folder-downloader/raw/master/download.py
  from download import download_folder
  download_folder(service, folder_id, './', folder_name)
  return folder_name

folder_download('1g58xFQ9aDcTPetma4blzVTQYX-QKkzNf')
# Out:
# 1JXVxKJgHVoO6d8Tw1YvUaVUo5icYP-qz Data_static_logs.csv text/csv (1/5)
# Download 100%.
# 1fZJeOSiSNJhEflCys-SU89DYVUNMGyx_ Duvernay application/vnd.google-apps.folder (2/5)
# 1nSduAg1dRkkuS8TLHDRo_W8pHmM__2Zn Duvernay application/vnd.google-apps.folder (1/1)
# 1Q7JqL9OEOQ6ElqgngcKHiuKGiVJgg3Xd Duvenay TrueTemp_Train.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (1/8)
# Download 100%.
# 1NtpKfoCBu8Ov4-rIsMftH2vfF1nsfBOb Duvernay DST BHT for SPE April 20 2021.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (2/8)
# Download 100%.
# 1bCdzvZtZ72Kk8w_wry-p07URdiEIkPg9 Duvernay DST Pressures SPE May 2 2021.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (3/8)
# Download 100%.
# 1S47FKEnpxJZjcxr_vmTM4DGnm4G2mj4X Duvernay formation tops SPE April 20 2021.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (4/8)
# Download 100%.
# 1TQC2CoMnpNq4ZQcEpbUTOIYAEovWQ7SS Duvernay well headers SPE April 21 2021 .xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (5/8)
# Download 100%.
# 1WnuwTEuTUjyA9jOFBDt5BWy9UONe7epz Mud log image files SPE April 20 2021.zip application/x-zip-compressed (6/8)
# Download 100%.
# 1XgZh03deOCzxI26X7WG4SV0nGKBGlh3C SPE Duvernay digital curves April 20 2021.zip application/x-zip-compressed (7/8)
# Download 100%.
# 151qd3TEzq4aKHnufkrWn1HAG7RUszPSI SPE Duvernay production summary April 20 2021.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (8/8)
# Download 100%.
# 1QegmxJ2nHms2-Nqc2nrn3yC-Xwo6BHKW Eaglebine application/vnd.google-apps.folder (3/5)
# 1CufAVasSEUUEMkxUm51-w3ioxYpEg4vw Eaglebine application/vnd.google-apps.folder (1/1)
# 1YYbt5CvUiI00YVQvElmqOXtxg7slA5pR EagleBine Casing production summary for SPE April21 2020.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (1/9)
# Download 100%.
# 1ILn0vNZeBXBK21pelBaRnH41SXUIoAjk Eaglebine BHT TSC data for SPE April 21 2020.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (2/9)
# Download 100%.
# 1LA5Z4ZJtPm4WegWC97DCLLs4GsEq9uA- Eaglebine TrueTemp_Train2.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (3/9)
# Download 100%.
# 18mff7adVKOo4Bmea5QDpcl6NcSyiftLw Eaglebine digital curves SPE Apr 20 2021.zip application/x-zip-compressed (4/9)
# Download 100%.
# 1_dUpTmE1Wv4LHBU-OhN67eHuIFHHPSqL Eaglebine formation tops SPE April 20 2021.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (5/9)
# Download 100%.
# 1lVOmkPQNcDHRXhgYfQabW853qiddyTO9 Eaglebine mud weight SPE April 21 2021.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (6/9)
# Download 100%.
# 15ssfVzwO4YoohKcMyh8oyGKRyUwS6hFj Eaglebine well headers SPE April 21 2021.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (7/9)
# Download 100%.
# 1y-PM0CTXEZ3Cw-IWTDZQhyQ5a_VkkSZh Mud log images SPE April 20 2021.zip application/x-zip-compressed (8/9)
# Download 100%.
# 1g2Alrm-LJUnMENUDbXaEz_6ODinQjHws SPE Eaglebine production summary April 20 2021.xlsx application/vnd.openxmlformats-officedocument.spreadsheetml.sheet (9/9)
# Download 100%.
# 1_T_GO0Ci4fzuo-hdZIGslfibQCHcveBZ set_assign.csv text/csv (4/5)
# Download 100%.
# 1ap8K65mXOUhrd3Xpnio89MXMXSxx-w6X well_log_files.zip application/x-zip-compressed (5/5)
# Download 100%.
# 'Data for Datathon'

# %%
# unzip some files
# !mkdir clean_las_files
! cd Data\ for\ Datathon && unzip well_log_files.zip -d /content/clean_las_files
# Out:
# Archive:  well_log_files.zip
#    creating: /content/clean_las_files/Clean_LAS/
#   inflating: /content/clean_las_files/Clean_LAS/CA100010107020W500_3067458_00001H5337365_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100010107020W500_3067458_00992H4184542.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100010608109W500_3067458_00002H1405557_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100010608109W500_3067458_00546H1280753.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100010904012W500_3067458_00003H4344853_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100010904012W500_3067458_00615H4348337.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100011206021W400_3067458_00004H4246284_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100011206021W400_3067458_01014H4242150.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100011506915W500_3067458_00005H3910764_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100011506915W500_3067458_00788H3910747.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100011804403W500_3067458_00006H3794594_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100011804403W500_3067458_00699H3794526.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100011806718W500_3067458_00007H3929205_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100011806718W500_3067458_00824H3926060.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012306427W500_3067458_00008H3920048_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012306427W500_3067458_00812H3920016.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012404516W502_3067458_00009H5351807_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012404516W502_3067458_00869H4232011.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012706026W400_3067458_00010H5359363_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012706026W400_3067458_00995H4306711.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012805703W500_3067458_00011H4243742_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012805703W500_3067458_00878H4243484.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012906918W500_3067458_00012H5352789_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100012906918W500_3067458_00891H4247300.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100013603712W500_3067458_00013H5339095_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100013603712W500_3067458_00876H4190450.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020106719W500_3067458_00014H5275665_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020106719W500_3067458_00639H1774198.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020107808W500_3067458_00015H5329708_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020107808W500_3067458_00524H1254812.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020206322W500_3067458_00016H5274990_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020206322W500_3067458_00604H1755444.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020206419W500_3067458_00017H5354861_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020206419W500_3067458_00944H4275833.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020206508W500_3067458_00018H4258879_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020206508W500_3067458_00855H4250742.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020403021W400_3067458_00019H5312253_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020403021W400_3067458_00765H3890341.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020605904W500_3067458_00020H5352186_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020605904W500_3067458_00948H4234750.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020606216W500_3067458_00021H5354669_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020606216W500_3067458_00586H4272203.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020606512W500_3067458_00022H5359547_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020606512W500_3067458_00961H4339460.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020807907W500_3067458_00023H1404598_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100020807907W500_3067458_00554H1404597.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021106720W500_3067458_00024H5359166_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021106720W500_3067458_01002H4294079.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021306113W500_3067458_00025H3921101_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021306113W500_3067458_00794H3915930.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021406411W500_3067458_00026H5359548_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021406411W500_3067458_01009H4338944.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021406418W500_3067458_00027H5360240_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021406418W500_3067458_00602H4348518.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021503426W400_3067458_00028H1828761_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021503426W400_3067458_00660H1828760.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021506315W500_3067458_00029H5325665_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021506315W500_3067458_00618H4170625.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021506419W500_3067458_00030H5355460_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021506419W500_3067458_00919H4277899.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021506718W500_3067458_00031H3907200_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021506718W500_3067458_00779H3907199.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021708007W500_3067458_00032H1406715_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021708007W500_3067458_00544H1275175.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021805706W500_3067458_00033H5337367_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021805706W500_3067458_01005H4185050.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021806218W500_3067458_00034H5336892_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021806218W500_3067458_00739H3865864.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021806318W500_3067458_00035H5354673_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021806318W500_3067458_00584H4272211.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021906119W500_3067458_00036H3849787_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100021906119W500_3067458_00721H5595411.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022005123W400_3067458_00037H3896892_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022005123W400_3067458_00771H3895133.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022006107W600_3067458_00038H1770300_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022006107W600_3067458_00611H1762333.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022007907W500_3067458_00039H1405766_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022007907W500_3067458_00520H1241834.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022008108W500_3067458_00040H1405373_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022008108W500_3067458_00531H1258328.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022106317W500_3067458_00041H5274991_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022106317W500_3067458_00607H1756354.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022208108W500_3067458_00042H5329709_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022208108W500_3067458_00516H1234632.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022306625W500_3067458_00043H5308161_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022306625W500_3067458_00720H3841125.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022406617W500_3067458_00044H5355785_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022406617W500_3067458_00985H4285856.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022706319W500_3067458_00045H5355786_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022706319W500_3067458_00977H4286399.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022706625W500_3067458_00046H5325667_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022706625W500_3067458_00514H4176882.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022806320W500_3067458_00047H5273174_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022806320W500_3067458_00697H3776827.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022806419W500_3067458_00048H5355568_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100022806419W500_3067458_00857H4281681.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023008008W500_3067458_00049H5330093_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023008008W500_3067458_00534H1259042.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023206413W500_3067458_00050H3930136_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023206413W500_3067458_00838H3930137.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023206414W500_3067458_00051H5278835_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023206414W500_3067458_00642H1776445.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023303322W400_3067458_00052H5336893_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023303322W400_3067458_00738H3865576.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023306507W500_3067458_00053H5351445_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023306507W500_3067458_00887H4220985.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023407808W500_3067458_00054H1405358_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023407808W500_3067458_00527H1255959.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023506212W500_3067458_00055H3916910_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023506212W500_3067458_00800H3916909.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023506213W500_3067458_00056H5354429_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023506213W500_3067458_00922H4267121.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023608010W500_3067458_00057H1401967_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100023608010W500_3067458_00542H1273995.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100030906512W500_3067458_00058H4343665_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100030906512W500_3067458_00910H4343560.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100031204517W500_3067458_00059H4214574_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100031204517W500_3067458_00583H4378754.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100031305615W500_3067458_00060H5359970_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100031305615W500_3067458_00580H4342191.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100031508009W500_3067458_00061H1408631_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100031508009W500_3067458_00556H1408630.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032106921W500_3067458_00062H5352247_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032106921W500_3067458_00888H4237619.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032205219W500_3067458_00063H4197757_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032205219W500_3067458_00590H4323448.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032206603W600_3067458_00064H1814063_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032206603W600_3067458_00659H1814206.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032405416W500_3067458_00065H3911646_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032405416W500_3067458_00792H3911644.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032506117W500_3067458_00066H5328554_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032506117W500_3067458_00911H4181755.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032604920W500_3067458_00067H4188910_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100032604920W500_3067458_00993H4184638.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100033006726W500_3067458_00068H3926909_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100033006726W500_3067458_00808H3919759.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100033008009W500_3067458_00069H5329714_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100033008009W500_3067458_00522H1250885.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100033206015W500_3067458_00070H5275566_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100033206015W500_3067458_00716H3836236.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100033206322W500_3067458_00071H3922149_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100033206322W500_3067458_00817H3922151.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040206609W500_3067458_00072H5359552_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040206609W500_3067458_00894H4339449.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040207011W500_3067458_00073H5359502_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040207011W500_3067458_00956H4331042.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040306718W500_3067458_00074H5355698_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040306718W500_3067458_00999H4283080.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040403610W500_3067458_00075H4265536_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040403610W500_3067458_00984H4261254.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040506215W500_3067458_00076H3850025_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040506215W500_3067458_00723H3850004.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040705920W400_3067458_00077H5339248_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040705920W400_3067458_01020H4191723.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040706512W500_3067458_00078H5360154_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040706512W500_3067458_00978H4344233.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040706523W500_3067458_00079H5275599_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040706523W500_3067458_00609H1759099.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040808007W500_3067458_00080H1372925_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040808007W500_3067458_00547H1281783.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040907910W500_3067458_00081H4261747_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100040907910W500_3067458_01004H4255065.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041007824W500_3067458_00082H5349337_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041007824W500_3067458_00875H4193875.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041106519W500_3067458_00083H5337024_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041106519W500_3067458_00747H3873262.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041206410W500_3067458_00084H5359503_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041206410W500_3067458_00926H4331327.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041206613W500_3067458_00085H3911892_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041206613W500_3067458_00797H3916011.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041206926W500_3067458_00086H1811112_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041206926W500_3067458_00649H1809074.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041407808W500_3067458_00087H5330222_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041407808W500_3067458_00550H1290682.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041603305W500_3067458_00088H5352190_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041603305W500_3067458_00991H4234639.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041606219W500_3067458_00089H5351769_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041606219W500_3067458_00947H4230915.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041706214W500_3067458_00090H5324948_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041706214W500_3067458_00643H4169843.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041708009W500_3067458_00091H5329715_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041708009W500_3067458_00525H1255200.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041806523W500_3067458_00092H5338797_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041806523W500_3067458_00596H4189804.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041903905W500_3067458_00093H5354263_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100041903905W500_3067458_01021H4266079.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042103812W500_3067458_00094H5346130_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042103812W500_3067458_00950H4191949.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042108108W500_3067458_00095H5330096_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042108108W500_3067458_00535H1260365.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042203707W500_3067458_00096H5336895_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042203707W500_3067458_00743H3866945.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042206623W500_3067458_00097H5332864_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042206623W500_3067458_00680H3481323.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042206918W500_3067458_00098H5352702_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042206918W500_3067458_00996H4244626.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042304007W500_3067458_00099H5273577_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042304007W500_3067458_00706H3805616.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042606601W600_3067458_00100H3923141_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042606601W600_3067458_00819H3923142.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042608008W500_3067458_00101H5329718_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042608008W500_3067458_00518H1236109.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042706322W500_3067458_00102H5296959_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042706322W500_3067458_00666H2454676.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042803323W400_3067458_00103H3954848_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042803323W400_3067458_00737H3864792.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042808108W500_3067458_00104H5329719_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100042808108W500_3067458_00519H1240559.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043008007W500_3067458_00105H1404081_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043008007W500_3067458_00553H1404080.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043106509W500_3067458_00106H5359555_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043106509W500_3067458_01016H4338957.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043107019W500_3067458_00107H1575747_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043107019W500_3067458_00557H1575749.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043206618W500_3067458_00108H5349309_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043206618W500_3067458_00957H4192268.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043306616W500_3067458_00109H3929250_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043306616W500_3067458_00826H3926189.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043406718W500_3067458_00110H5354011_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043406718W500_3067458_00970H4257176.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043505018W500_3067458_00111H3918564_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043505018W500_3067458_00803H3918098.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043506919W500_3067458_00112H3927643_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043506919W500_3067458_00832H3927642.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043606507W500_3067458_00113H5349310_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100043606507W500_3067458_01018H4193554.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100050506418W500_3067458_00114H5352194_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100050506418W500_3067458_00927H4234641.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100050705624W502_3067458_00115H3726941_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100050705624W502_3067458_00688H3726939.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100050806905W600_3067458_00116H5336898_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100050806905W600_3067458_00740H3865869.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100051006826W500_3067458_00117H1811945_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100051006826W500_3067458_00652H1810652.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100052107723W500_3067458_00118H3908283_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100052107723W500_3067458_00782H3908292.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100052206625W500_3067458_00119H3905691_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100052206625W500_3067458_00777H3905693.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053106213W500_3067458_00120H3929272_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053106213W500_3067458_00810H3919946.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053106224W500_3067458_00121H3929260_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053106224W500_3067458_00827H3926193.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053106506W500_3067458_00122H5354052_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053106506W500_3067458_00865H4262594.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053408009W500_3067458_00123H1405350_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053408009W500_3067458_00526H1255570.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053606118W500_3067458_00124H4072347_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100053606118W500_3067458_00612H4071776.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060106315W500_3067458_00125H5318835_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060106315W500_3067458_00718H4018285.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060305107W500_3067458_00126H5355714_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060305107W500_3067458_00570H4284245.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060306506W500_3067458_00127H5339253_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060306506W500_3067458_00858H4191762.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060404101W500_3067458_00128H3805477_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060404101W500_3067458_00704H3804842.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060505514W500_3067458_00129H5337368_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060505514W500_3067458_00925H4183312.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060506322W500_3067458_00130H5275668_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060506322W500_3067458_00621H1769341.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060603720W400_3067458_00131H5337027_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060603720W400_3067458_00752H3877030.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060605514W500_3067458_00132H5360247_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060605514W500_3067458_00568H4357525.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060606219W500_3067458_00133H4343522_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060606219W500_3067458_00558H1676006.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060606515W500_3067458_00134H3920053_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060606515W500_3067458_00815H3920232.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060608108W500_3067458_00135H1286674_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060608108W500_3067458_00517H1235717.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060706022W500_3067458_00136H5359174_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060706022W500_3067458_00901H4295425.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060805217W500_3067458_00137H5359505_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060805217W500_3067458_00581H4321522.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060807808W500_3067458_00138H1405862_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060807808W500_3067458_00548H1283400.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060905918W500_3067458_00139H5275602_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100060905918W500_3067458_00608H1756437.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061004119W400_3067458_00140H5349315_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061004119W400_3067458_00900H4192243.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061005216W500_3067458_00141H5296970_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061005216W500_3067458_00662H2018239.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061006117W500_3067458_00142H5275573_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061006117W500_3067458_00715H3836231.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061103324W400_3067458_00143H3942461_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061103324W400_3067458_00848H3942460.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061106926W500_3067458_00144H3855305_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061106926W500_3067458_00719H3839960.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061204211W500_3067458_00145H5275020_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061204211W500_3067458_00711H3806639.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061305216W500_3067458_00146H3881978_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061305216W500_3067458_00759H3881972.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061306018W500_3067458_00147H5332747_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061306018W500_3067458_00595H1746783.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061307518W500_3067458_00148H3918144_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061307518W500_3067458_00806H3918454.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061403127W400_3067458_00149H3954850_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061403127W400_3067458_00852H3954831.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061404814W400_3067458_00150H3950761_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061404814W400_3067458_00849H3950747.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061406920W500_3067458_00151H3918566_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061406920W500_3067458_00807H3918558.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061408009W500_3067458_00152H1372903_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061408009W500_3067458_00551H1372500.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061504803W500_3067458_00153H5275022_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061504803W500_3067458_00708H3805838.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061605518W500_3067458_00154H5352196_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061605518W500_3067458_00640H4232748.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061608009W500_3067458_00155H1403618_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061608009W500_3067458_00541H1270743.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061706804W600_3067458_00156H5312825_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061706804W600_3067458_00772H3896210.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061805414W500_3067458_00157H3935798_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100061805414W500_3067458_00843H4373688.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062005015W500_3067458_00158H5313778_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062005015W500_3067458_00774H3897576.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062007823W500_3067458_00159H4219020_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062007823W500_3067458_00945H4219019.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062105118W500_3067458_00160H3930370_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062105118W500_3067458_00833H3928393.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062106425W500_3067458_00161H3889522_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062106425W500_3067458_00763H3889514.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062203325W400_3067458_00162H3949223_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062203325W400_3067458_00661H1830277.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062303619W400_3067458_00163H5346135_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062303619W400_3067458_00997H4191983.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062306318W500_3067458_00164H5346136_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062306318W500_3067458_00960H4191969.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062307218W500_3067458_00165H5339256_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062307218W500_3067458_00965H4191536.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062406517W500_3067458_00166H4149945_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062406517W500_3067458_00717H4137411.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062506412W500_3067458_00167H3910896_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062506412W500_3067458_00790H3910897.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062604715W500_3067458_00168H5311537_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062604715W500_3067458_00760H3887153.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062605918W500_3067458_00169H5275670_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062605918W500_3067458_00623H1769426.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062705713W500_3067458_00170H4260782_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062705713W500_3067458_00886H4193885.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062804714W500_3067458_00171H5311043_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062804714W500_3067458_00754H3879883.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062904514W500_3067458_00172H4232994_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062904514W500_3067458_00599H4358307.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062904601W500_3067458_00173H3805633_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062904601W500_3067458_00701H3804498.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062905416W500_3067458_00174H5360248_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062905416W500_3067458_00756H4345521.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062905913W500_3067458_00175H5346137_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062905913W500_3067458_00963H4191970.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062906118W500_3067458_00176H1813968_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100062906118W500_3067458_00654H1810663.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063007223W500_3067458_00177H4190984_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063007223W500_3067458_00930H4179635.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063008009W500_3067458_00178H1373233_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063008009W500_3067458_00539H1264913.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063104713W500_3067458_00179H5311538_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063104713W500_3067458_00762H3889365.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063205214W500_3067458_00180H5351458_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063205214W500_3067458_00943H4220006.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063206123W500_3067458_00181H5355716_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063206123W500_3067458_00564H4284499.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063306117W500_3067458_00182H5342431_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063306117W500_3067458_00904H4191821.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063306217W500_3067458_00183H5296977_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063306217W500_3067458_00678H3475085.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063405415W500_3067458_00184H5309989_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063405415W500_3067458_00571H4348584.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063504615W400_3067458_00185H3950765_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063504615W400_3067458_00841H3931149.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063506018W500_3067458_00186H5336206_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063506018W500_3067458_00736H3864200.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063507018W500_3067458_00187H3921110_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063507018W500_3067458_00816H3921087.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063605819W500_3067458_00188H5296978_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063605819W500_3067458_00673H3473002.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063606213W500_3067458_00189H5360160_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063606213W500_3067458_00890H4343576.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063606312W500_3067458_00190H5337032_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063606312W500_3067458_00748H3873271.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063606625W500_3067458_00191H1810654_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100063606625W500_3067458_00653H1810656.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070104103W500_3067458_00192H3804506_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070104103W500_3067458_00702H3804505.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070104810W500_3067458_00193H3804718_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070104810W500_3067458_00700H3804084.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070206217W500_3067458_00194H5351004_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070206217W500_3067458_00884H4205186.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070404912W500_3067458_00195H5296979_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070404912W500_3067458_00667H2478993.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070505818W500_3067458_00196H1812728_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070505818W500_3067458_00651H1810598.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070507708W500_3067458_00197H5345608_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070507708W500_3067458_00967H4191838.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070606504W500_3067458_00198H5342433_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070606504W500_3067458_00905H4191824.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070706116W500_3067458_00199H5336901_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070706116W500_3067458_00745H3868674.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070706314W500_3067458_00200H5352796_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070706314W500_3067458_00868H4248755.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070906818W500_3067458_00201H3910776_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070906818W500_3067458_00776H3904318.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070907618W500_3067458_00202H3920058_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100070907618W500_3067458_00813H3920028.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071005813W500_3067458_00203H5352798_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071005813W500_3067458_01012H4247814.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071106425W500_3067458_00204H5310584_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071106425W500_3067458_00560H1678444.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071306526W500_3067458_00205H3941708_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071306526W500_3067458_00846H3941815.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071406218W500_3067458_00206H5325672_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071406218W500_3067458_00633H4177350.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071406220W500_3067458_00207H5355721_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071406220W500_3067458_00769H4284930.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071406317W500_3067458_00208H5339261_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071406317W500_3067458_01017H4191172.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071505518W500_3067458_00209H5362689_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071505518W500_3067458_00614H1762418.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071606217W500_3067458_00210H5324895_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071606217W500_3067458_00897H4155931.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071606224W500_3067458_00211H5338318_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071606224W500_3067458_00989H4186582.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071906101W500_3067458_00212H4242673_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100071906101W500_3067458_00881H4242671.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072103910W500_3067458_00213H5275672_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072103910W500_3067458_00620H1766981.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072106223W500_3067458_00214H5275673_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072106223W500_3067458_00637H1772521.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072206324W500_3067458_00215H5328557_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072206324W500_3067458_00877H4181870.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072206419W500_3067458_00216H5275674_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072206419W500_3067458_00632H1771157.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072304811W400_3067458_00217H5315503_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072304811W400_3067458_00835H5315099.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072504012W500_3067458_00218H5325674_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072504012W500_3067458_00920H4171133.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072504410W500_3067458_00219H1813001_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072504410W500_3067458_00655H1811231.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072507623W500_3067458_00220H3919794_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072507623W500_3067458_00796H3915975.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072605920W500_3067458_00221H5296985_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072605920W500_3067458_00671H3471288.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072706318W500_3067458_00222H3851423_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072706318W500_3067458_00724H3851415.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072706626W500_3067458_00223H3905639_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072706626W500_3067458_00773H3896281.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072805217W500_3067458_00224H5324771_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072805217W500_3067458_00899H4153460.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072907222W500_3067458_00225H5351005_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100072907222W500_3067458_01013H4197325.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073005022W400_3067458_00226H5315504_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073005022W400_3067458_00836H5315105.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073008009W500_3067458_00227H1404024_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073008009W500_3067458_00552H1404023.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073207810W500_3067458_00228H5351775_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073207810W500_3067458_00902H4226296.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073306319W500_3067458_00229H5275675_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073306319W500_3067458_00638H1773536.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073405315W500_3067458_00230H3904038_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073405315W500_3067458_00775H3904036.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073506014W500_3067458_00231H5275576_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073506014W500_3067458_00714H3833238.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073606118W500_3067458_00232H5333217_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100073606118W500_3067458_00681H3481628.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100080903909W500_3067458_00233H5337223_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100080903909W500_3067458_00644H4183206.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100080907321W500_3067458_00234H3929209_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100080907321W500_3067458_00825H3926068.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100081504804W500_3067458_00235H5310304_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100081504804W500_3067458_00851H4120018.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100081805214W500_3067458_00236H3929228_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100081805214W500_3067458_00811H3919952.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100082003821W400_3067458_00237H5311541_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100082003821W400_3067458_00758H3880657.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100082304316W400_3067458_00238H4260991_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100082304316W400_3067458_00879H4249361.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100082304316W500_3067458_00239H4212198_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100082304316W500_3067458_00589H4366879.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100083005205W500_3067458_00240H3805274_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100083005205W500_3067458_00705H3805271.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100083303122W400_3067458_00241H3986150_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100083303122W400_3067458_00732H3861400.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100083305512W500_3067458_00242H5351955_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100083305512W500_3067458_01001H4231732.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100083403425W400_3067458_00243H3916603_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100083403425W400_3067458_00798H3916598.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100090107716W500_3067458_00244H5351006_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100090107716W500_3067458_00976H4199556.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100090605211W500_3067458_00245H5321676_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100090605211W500_3067458_00515H4040812.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100091703425W400_3067458_00246H5336148_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100091703425W400_3067458_00731H3860789.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100091804909W500_3067458_00247H3805998_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100091804909W500_3067458_00707H3805668.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100092206315W500_3067458_00248H5354018_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100092206315W500_3067458_00885H4253274.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100092304214W400_3067458_00249H4216017_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100092304214W400_3067458_00964H4185977.LAS
#   inflating: /content/clean_las_files/Clean_LAS/CA100092508109W500_3067458_00250H1272213_W.LAS
# ...
#   inflating: /content/clean_las_files/Clean_LAS/US42283314640000_3067463_00305H800879_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42283314670000_3067463_00306H654264.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42283315220000_3067463_00307H654667.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42283315230000_3067463_00308H654617.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42283315400000_3067463_00309H654623.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42283315470000_3067463_00310H667330.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42283315470000_3067463_00311H1597675_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42283315560000_3067463_00312H582951.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42283315610000_3067463_00313H319058.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42285307220000_3067463_00314H271333.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42285307220000_3067463_00315H271852_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42285313350000_3067463_00316H154996.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42285313800000_3067463_00317H148477.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42285315200000_3067463_00318H5298273.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287305100000_3067463_00319H3950937.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287305130000_3067463_00320H161638.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287305130000_3067463_00321H1767402_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287306420000_3067463_00322H1603833.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287309060000_3067463_00323H3958828.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287309140000_3067463_00324H1638301.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287309140000_3067463_00325H1752189_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287309240000_3067463_00326H228822.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287309240000_3067463_00327H3717521_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287309370000_3067463_00328H1652641.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287309540000_3067463_00329H1097485.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287312020000_3067463_00330H161427.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287312020000_3067463_00331H1641501_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287312490000_3067463_00332H160857.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287312490000_3067463_00333H1659831_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287312500000_3067463_00334H228825.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287312500000_3067463_00335H1656206_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287312830000_3067463_00336H161391.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287312830000_3067463_00337H1656208_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287315320000_3067463_00338H161428.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287315320000_3067463_00339H1656214_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287325030000_3067463_00340H160516.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287325060000_3067463_00341H847333.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42287325060000_3067463_00342H1656224_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289301060000_3067463_00343H213492.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289301060000_3067463_00344H1791750_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289303540000_3067463_00345H136123.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289303540000_3067463_00346H1792123_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289304430000_3067463_00347H194685.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289304430000_3067463_00348H3610882_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289304700000_3067463_00349H185886.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289304700000_3067463_00350H3766528_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289305780000_3067463_00351H413490.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289305780000_3067463_00352H3757663_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289306600000_3067463_00353H1752398.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289306650000_3067463_00354H181356.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289306650000_3067463_00355H3715612_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289308110000_3067463_00356H234972.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289308110000_3067463_00357H235469_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289309370000_3067463_00358H1752404.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289309440000_3067463_00359H1752408.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289309510000_3067463_00360H1752416.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289309850000_3067463_00361H1758549.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289310220000_3067463_00362H1797658.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289310220000_3067463_00363H1797659_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289310900000_3067463_00364H410565.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289310900000_3067463_00365H1782674_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289310950000_3067463_00366H990549.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289310950000_3067463_00367H3763087_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289311110000_3067463_00368H413512.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289311110000_3067463_00369H3716323_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312310000_3067463_00370H183935.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312310000_3067463_00371H1782569_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312660000_3067463_00372H1603064.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312660000_3067463_00373H1622705_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312770000_3067463_00374H3806714.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312770000_3067463_00375H3848130_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312850000_3067463_00376H181478.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312850000_3067463_00377H3796755_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312900000_3067463_00378H1691338.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289312900000_3067463_00379H1695699_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289313060000_3067463_00380H184192.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289313060000_3067463_00381H3749768_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289313140000_3067463_00382H1638780.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289313140000_3067463_00383H1679719_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289313210000_3067463_00384H813499.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289313210000_3067463_00385H3712019_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289313250000_3067463_00386H943965.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289313250000_3067463_00387H3765839_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289315440000_3067463_00388H3765504.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289315440000_3067463_00389H3782543_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289318670000_3067463_00390H4106077.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42289318670000_3067463_00391H4885436_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42293304160000_3067463_00392H1452036.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42293304380000_3067463_00393H467562.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42293304520000_3067463_00394H1159604.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42293305010000_3067463_00395H157563.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42293308740000_3067463_00396H1439907.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42293309280000_3067463_00397H1445825.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42293312300000_3067463_00398H195276.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42311001580000_3067463_00399H181603.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42311001580000_3067463_00400H770972_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42311006770000_3067463_00401H370598.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42311006770000_3067463_00402H771224_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42311013640000_3067463_00403H164358.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42311013640000_3067463_00404H774710_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42311317850000_3067463_00405H4882219.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42311317850000_3067463_00406H781031_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313300420000_3067463_00407H157576.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313302370000_3067463_00408H165800.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313302910000_3067463_00409H149990.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313302910000_3067463_00410H1604652_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313304420000_3067463_00411H1139555.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313304420000_3067463_00412H1603745_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313305590000_3067463_00413H1054776.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313311010000_3067463_00414H5312283_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42313311010000_3067463_00415H5309762.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323000820000_3067463_00416H182295.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323300710000_3067463_00417H377717.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323300720000_3067463_00418H188170.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323300720000_3067463_00419H1649920_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323306640000_3067463_00420H812152.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323307960000_3067463_00421H192736.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323312460000_3067463_00422H288273.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323312460000_3067463_00423H860686_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323312560000_3067463_00424H386497.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323312560000_3067463_00425H882861_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323312660000_3067463_00426H386803.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323312660000_3067463_00427H869904_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323324740000_3067463_00428H382946.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323324740000_3067463_00429H6960069_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323329160000_3067463_00430H1105618.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42323329160000_3067463_00431H1595530_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395300370000_3067463_00432H472853.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395302780000_3067463_00433H159246.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395302880000_3067463_00434H355487.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395302880000_3067463_00435H214380_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395302890000_3067463_00436H988493.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395302890000_3067463_00437H1742351_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395303030000_3067463_00438H991293.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395303030000_3067463_00439H1733698_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395303790000_3067463_00440H939657.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395304350000_3067463_00441H166392.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395304440000_3067463_00442H335521.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395304830000_3067463_00443H166815.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42395307330000_3067463_00444H410791.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42477303240000_3067463_00445H1644926.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42477303240000_3067463_00446H1743640_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42477304680000_3067463_00447H643764.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42477305280000_3067463_00448H208856.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42477305490000_3067463_00449H196016.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42479352780000_3067463_00450H665625.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493302300000_3067463_00451H1649644_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493302300000_3067463_00452H1095606.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493303910000_3067463_00453H1083077.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493306840000_3067463_00454H669290.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493307780000_3067463_00455H1048710.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493308380000_3067463_00456H1053480.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493309720000_3067463_00457H669418.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493310750000_3067463_00458H1652820_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493310750000_3067463_00459H1101520.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493311060000_3067463_00460H1648645_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493311060000_3067463_00461H1096463.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493311680000_3067463_00462H1048440.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493312560000_3067463_00463H1108260.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493316260000_3067463_00464H1047822.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493316680000_3067463_00465H1047823.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493317790000_3067463_00466H1055535.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493318190000_3067463_00467H1095771.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493319370000_3067463_00468H669422.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493322270000_3067463_00469H1651919_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42493322270000_3067463_00470H1070771.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42507007550000_3067463_00471H192583.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42507312420000_3067463_00472H643154.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42507312960000_3067463_00473H184166.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42507326870000_3067463_00474H1599140_W.LAS
#   inflating: /content/clean_las_files/Clean_LAS/US42507326870000_3067463_00475H1002112.LAS

# %%
# set paths of different subdirectories
dir_eaglebine = 'Data for Datathon/Eaglebine/Eaglebine/'
dir_duvernay = 'Data for Datathon/Duvernay/Duvernay/'

# %% [markdown]
# # 2 Organize Eaglebine temperature data

# %% [markdown]
# ## 2.1 read in BHT

# %%
Eaglebine_BHT = pd.read_excel(dir_eaglebine+'Eaglebine BHT TSC data for SPE April 21 2020.xlsx')
Eaglebine_BHT['TempC_BHT'] = (Eaglebine_BHT['BHTorMRT (maximum recorded temperature) oF'] - 32) * (5./9.)
Eaglebine_BHT.head()
# Out:
#               UWI    SurfLat   SurfLong  TD (ft)  GL(ft)  \
# 0  42013301410000  28.690426 -98.470138  19629.0  345.90
# 1  42013301930000  28.779921 -98.208313  10775.0  397.40
# 2  42013302760000  28.994360 -98.421799   6168.0  460.40
# 3  42013305480000  28.759118 -98.156410   8198.0  410.40
# 4  42013310190000  28.817400 -98.155319  11000.0  508.92
#
#    BHT_below sea level (ft)  BHT_ subsurface (ft)  \
# 0                  12222.50               12568.4
# 1                  10396.00               10793.4
# 2                   5733.00                6193.4
# 3                   7806.00                8216.4
# 4                  10509.48               11018.4
#
#    BHTorMRT (maximum recorded temperature) oF  \
# 0                                       143.0
# 1                                       225.0
# 2                                       150.0
# 3                                       170.0
# 4                                       210.0
#
#    TSC or ORT (time since circulation or original recorded time in hours)  \
# 0                                               5.50
# 1                                              11.00
# 2                                               5.50
# 3                                               5.00
# 4                                               7.75
#
#     TempC_BHT
# 0   61.666667
# 1  107.222222
# 2   65.555556
# 3   76.666667
# 4   98.888889

# %%
print("number of unique wells: " + str(len(pd.unique(Eaglebine_BHT['UWI']))))
# Out:
# number of unique wells: 324

# %% [markdown]
# ## 2.2 Read in Eaglebine synthetic "true formation temperature"

# %%
Eaglebine_Truth = pd.read_excel(dir_eaglebine+'Eaglebine TrueTemp_Train2.xlsx')
Eaglebine_Truth.head()
# Out:
#               UWI  Depth sub-sea (feet)  True Temperature   (oF)
# 0  42013301410000                  -350                    70.33
# 1  42013301410000                  -300                    70.33
# 2  42013301410000                  -250                    70.33
# 3  42013301410000                  -200                    71.49
# 4  42013301410000                  -150                    72.66

# %%
# convert to Celsius
Eaglebine_Truth['TempTrue_degC'] = (Eaglebine_Truth['True Temperature   (oF)'] - 32) * (5./9.)

# %%
print("number of unique wells in Eaglebine in training set: " + str(len(pd.unique(Eaglebine_Truth['UWI']))))
# Out:
# number of unique wells in Eaglebine in training set: 243

# %% [markdown]
# ## 2.3 Combine measured BHT and true temperature

# %%
Eaglebine_Combined = Eaglebine_BHT.merge(Eaglebine_Truth, on='UWI', how='left')

# %%
# only keep from the synthetic data, the temperature at the elevation closest to the model
Eaglebine_Combined['diff_depth'] = Eaglebine_Combined['Depth sub-sea (feet)']-Eaglebine_Combined['BHT_below sea level (ft)']
Eaglebine_Combined['diff_depth_abs'] = np.abs(Eaglebine_Combined['diff_depth'])
idx = Eaglebine_Combined.groupby(['UWI'])['diff_depth_abs'].transform(min) == Eaglebine_Combined['diff_depth_abs']
TrueTempUWI = Eaglebine_Combined.loc[idx, ['UWI', 'diff_depth_abs', 'TempTrue_degC']]
TrueTempUWI = TrueTempUWI.copy(deep=True)
Eaglebine_Combined_cln = Eaglebine_BHT.merge(TrueTempUWI, on='UWI', how='left')
Eaglebine_Combined_cln.head()
# Out:
#               UWI    SurfLat   SurfLong  TD (ft)  GL(ft)  \
# 0  42013301410000  28.690426 -98.470138  19629.0  345.90
# 1  42013301930000  28.779921 -98.208313  10775.0  397.40
# 2  42013302760000  28.994360 -98.421799   6168.0  460.40
# 3  42013305480000  28.759118 -98.156410   8198.0  410.40
# 4  42013310190000  28.817400 -98.155319  11000.0  508.92
#
#    BHT_below sea level (ft)  BHT_ subsurface (ft)  \
# 0                  12222.50               12568.4
# 1                  10396.00               10793.4
# 2                   5733.00                6193.4
# 3                   7806.00                8216.4
# 4                  10509.48               11018.4
#
#    BHTorMRT (maximum recorded temperature) oF  \
# 0                                       143.0
# 1                                       225.0
# 2                                       150.0
# 3                                       170.0
# 4                                       210.0
#
#    TSC or ORT (time since circulation or original recorded time in hours)  \
# 0                                               5.50
# 1                                              11.00
# 2                                               5.50
# 3                                               5.00
# 4                                               7.75
#
#     TempC_BHT  diff_depth_abs  TempTrue_degC
# 0   61.666667           22.50     141.555556
# 1  107.222222            4.00     132.038889
# 2   65.555556           17.00      89.161111
# 3   76.666667            6.00     107.961111
# 4   98.888889            9.48     133.722222

# %%
len(Eaglebine_Combined_cln)
# Out:
# 324

# %% [markdown]
# ## 2.4 Read in static temperature information and merge into dataset

# %%
Static_log_temp = pd.read_csv('Data for Datathon/Data_static_logs.csv')
Static_log_temp.head()
# Out:
#           Well_ID  Depth (ft)  Temp (degC)      Field
# 0  42013301930000     10700.0   132.778000  Eaglebine
# 1  42041305800000      7360.0    82.777778  Eaglebine
# 2  42041311700000      7828.0   118.888889  Eaglebine
# 3  42041311980000      7954.0   105.000000  Eaglebine
# 4  42051305380000      8380.0   111.111111  Eaglebine

# %%
Eaglebine_Combined_cln['UWI'] = Eaglebine_Combined_cln['UWI'].astype(str)
Eaglebine_Combined_cln = Eaglebine_Combined_cln.copy(deep=True)
Eaglebine_Combined_cln['TrueTemp_datasource_syn'] = 'synthetic'
Static_log_temp['TrueTemp_datasource_stat'] = 'static_temp_logs'
Eaglebine_Combined_stat = Eaglebine_Combined_cln.merge(Static_log_temp, left_on='UWI',right_on='Well_ID', how='left')

# %%
# Coalesce columns together with priority for true temperature measurements
Eaglebine_Combined_stat['TempC_Fin'] = Eaglebine_Combined_stat['Temp (degC)'].fillna(Eaglebine_Combined_stat['TempTrue_degC'])
Eaglebine_Combined_stat['TrueTemp_datasource'] = Eaglebine_Combined_stat['TrueTemp_datasource_stat'].fillna(Eaglebine_Combined_stat['TrueTemp_datasource_syn'])
Eaglebine_Combined_stat.head()
# Out:
#               UWI    SurfLat   SurfLong  TD (ft)  GL(ft)  \
# 0  42013301410000  28.690426 -98.470138  19629.0  345.90
# 1  42013301930000  28.779921 -98.208313  10775.0  397.40
# 2  42013302760000  28.994360 -98.421799   6168.0  460.40
# 3  42013305480000  28.759118 -98.156410   8198.0  410.40
# 4  42013310190000  28.817400 -98.155319  11000.0  508.92
#
#    BHT_below sea level (ft)  BHT_ subsurface (ft)  \
# 0                  12222.50               12568.4
# 1                  10396.00               10793.4
# 2                   5733.00                6193.4
# 3                   7806.00                8216.4
# 4                  10509.48               11018.4
#
#    BHTorMRT (maximum recorded temperature) oF  \
# 0                                       143.0
# 1                                       225.0
# 2                                       150.0
# 3                                       170.0
# 4                                       210.0
#
#    TSC or ORT (time since circulation or original recorded time in hours)  \
# 0                                               5.50
# 1                                              11.00
# 2                                               5.50
# 3                                               5.00
# 4                                               7.75
#
#     TempC_BHT  diff_depth_abs  TempTrue_degC TrueTemp_datasource_syn  \
# 0   61.666667           22.50     141.555556               synthetic
# 1  107.222222            4.00     132.038889               synthetic
# 2   65.555556           17.00      89.161111               synthetic
# 3   76.666667            6.00     107.961111               synthetic
# 4   98.888889            9.48     133.722222               synthetic
#
#           Well_ID  Depth (ft)  Temp (degC)      Field  \
# 0             NaN         NaN          NaN        NaN
# 1  42013301930000     10700.0      132.778  Eaglebine
# 2             NaN         NaN          NaN        NaN
# 3             NaN         NaN          NaN        NaN
# 4             NaN         NaN          NaN        NaN
#
#   TrueTemp_datasource_stat   TempC_Fin TrueTemp_datasource
# 0                      NaN  141.555556           synthetic
# 1         static_temp_logs  132.778000    static_temp_logs
# 2                      NaN   89.161111           synthetic
# 3                      NaN  107.961111           synthetic
# 4                      NaN  133.722222           synthetic

# %% [markdown]
# ## 2.5 plot the eaglebine temperature data

# %%
import matplotlib.pyplot as plt
plt.close('all')
fig, ax = plt.subplots(1, 1, figsize=(4,4))

sns.scatterplot(data=Eaglebine_Combined_stat, x="TempC_BHT", y="TempC_Fin", hue='BHT_below sea level (ft)', ax=ax)

ax.set_xlim([30, 220])
ax.set_ylim([30, 220])
ax.plot([0, 220], [0, 220])
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# # 3 Organize Duvernay temperature data

# %% [markdown]
# ## 3.1 Read in DST BHT input and "true temp" synthetic data

# %%
Duvernay_Truth = pd.read_excel(dir_duvernay+'Duvenay TrueTemp_Train.xlsx')
Duvernay_DST = pd.read_excel(dir_duvernay+'Duvernay DST BHT for SPE April 20 2021.xlsx')
Duvernay_Truth.head()
# Out:
#                 UWI  Depths subsea (m)  True Temperature (oC)
# 0  100010107020W500               -720                   2.53
# 1  100010107020W500               -700                   2.54
# 2  100010107020W500               -680                   2.54
# 3  100010107020W500               -660                   3.30
# 4  100010107020W500               -640                   4.06

# %%
# add in an extra column calculating the depth sub sea (elevation-depth)*-1 
Duvernay_DST['Depth_SS(m)']=-1*(Duvernay_DST['elevation M above sea level']-(Duvernay_DST['DST Start Depth (MD) (m)']+Duvernay_DST['DST End Depth (MD) (m)'])/2)
Duvernay_DST.head()
# Out:
#             Well ID  DST Start Depth (MD) (m)  DST End Depth (MD) (m)  \
# 0  100010107020W500                    1410.6                  1423.4
# 1  100010608109W500                    1686.0                  1694.0
# 2  100010904012W500                    3698.0                  3718.0
# 3  100011206021W400                     822.0                   825.0
# 4  100011506915W500                    1801.0                  1818.0
#
#    DST Bottom Hole Temp. (degC)  DST Test Date Test Type DST Misrun  \
# 0                         48.33          26025       DST          N
# 1                         34.26          33647       DST          N
# 2                        104.40          30798       LRT          N
# 3                         29.00          29543       DST          N
# 4                         64.00          30760       DST          N
#
#    DST Number Formation DSTd  Unnamed: 9  elevation M above sea level  \
# 0           2      TRmontney         NaN                        701.0
# 1           1        Dmuskeg         NaN                        645.6
# 2           1        Melkton         NaN                       1283.8
# 3           4      Dwintrbrn         NaN                        651.6
# 4           4       Dwabamun         NaN                        873.1
#
#                 UWI  Depth_SS(m)
# 0  100010107020W500        716.0
# 1  100010608109W500       1044.4
# 2  100010904012W500       2424.2
# 3  100011206021W400        171.9
# 4  100011506915W500        936.4

# %%
# merge
Duvernay_Combined = Duvernay_DST.merge(Duvernay_Truth, on='UWI', how='left')
Duvernay_Combined.head()
# Out:
#             Well ID  DST Start Depth (MD) (m)  DST End Depth (MD) (m)  \
# 0  100010107020W500                    1410.6                  1423.4
# 1  100010107020W500                    1410.6                  1423.4
# 2  100010107020W500                    1410.6                  1423.4
# 3  100010107020W500                    1410.6                  1423.4
# 4  100010107020W500                    1410.6                  1423.4
#
#    DST Bottom Hole Temp. (degC)  DST Test Date Test Type DST Misrun  \
# 0                         48.33          26025       DST          N
# 1                         48.33          26025       DST          N
# 2                         48.33          26025       DST          N
# 3                         48.33          26025       DST          N
# 4                         48.33          26025       DST          N
#
#    DST Number Formation DSTd  Unnamed: 9  elevation M above sea level  \
# 0           2      TRmontney         NaN                        701.0
# 1           2      TRmontney         NaN                        701.0
# 2           2      TRmontney         NaN                        701.0
# 3           2      TRmontney         NaN                        701.0
# 4           2      TRmontney         NaN                        701.0
#
#                 UWI  Depth_SS(m)  Depths subsea (m)  True Temperature (oC)
# 0  100010107020W500        716.0             -720.0                   2.53
# 1  100010107020W500        716.0             -700.0                   2.54
# 2  100010107020W500        716.0             -680.0                   2.54
# 3  100010107020W500        716.0             -660.0                   3.30
# 4  100010107020W500        716.0             -640.0                   4.06

# %%
# keep only the synthetic model temperature data for the relevant depths for which there is BHT measurement
Duvernay_Combined['diff_depth'] = Duvernay_Combined['Depth_SS(m)']-Duvernay_Combined['Depths subsea (m)']
Duvernay_Combined['diff_depth_abs'] = np.abs(Duvernay_Combined['diff_depth'])
idx = Duvernay_Combined.groupby(['UWI'])['diff_depth_abs'].transform(min) == Duvernay_Combined['diff_depth_abs']

TrueTempUWI = Duvernay_Combined.loc[idx, ['UWI', 'diff_depth_abs', 'True Temperature (oC)']]
TrueTempUWI = TrueTempUWI.copy(deep=True)
Duvernay_Combined_cln = Duvernay_DST.merge(TrueTempUWI, on='UWI', how='left')
Duvernay_Combined_cln = Duvernay_Combined_cln.drop_duplicates(['UWI'])
Duvernay_Combined_cln.head()
# Out:
#             Well ID  DST Start Depth (MD) (m)  DST End Depth (MD) (m)  \
# 0  100010107020W500                    1410.6                  1423.4
# 1  100010608109W500                    1686.0                  1694.0
# 2  100010904012W500                    3698.0                  3718.0
# 3  100011206021W400                     822.0                   825.0
# 4  100011506915W500                    1801.0                  1818.0
#
#    DST Bottom Hole Temp. (degC)  DST Test Date Test Type DST Misrun  \
# 0                         48.33          26025       DST          N
# 1                         34.26          33647       DST          N
# 2                        104.40          30798       LRT          N
# 3                         29.00          29543       DST          N
# 4                         64.00          30760       DST          N
#
#    DST Number Formation DSTd  Unnamed: 9  elevation M above sea level  \
# 0           2      TRmontney         NaN                        701.0
# 1           1        Dmuskeg         NaN                        645.6
# 2           1        Melkton         NaN                       1283.8
# 3           4      Dwintrbrn         NaN                        651.6
# 4           4       Dwabamun         NaN                        873.1
#
#                 UWI  Depth_SS(m)  diff_depth_abs  True Temperature (oC)
# 0  100010107020W500        716.0             4.0                  60.97
# 1  100010608109W500       1044.4             4.4                  63.98
# 2  100010904012W500       2424.2             NaN                    NaN
# 3  100011206021W400        171.9             8.1                  39.07
# 4  100011506915W500        936.4             3.6                  69.47

# %%
len(Duvernay_Combined_cln)
# Out:
# 512

# %% [markdown]
# ## 3.2 Merge in static temperature log data

# %%
Duvernay_Combined_cln['UWI'] = Duvernay_Combined_cln['UWI'].astype(str)
Duvernay_Combined_cln = Duvernay_Combined_cln.copy(deep=True)
Duvernay_Combined_cln['TrueTemp_datasource_syn'] = 'synthetic'
Static_log_temp['TrueTemp_datasource_stat'] = 'static_temp_logs'
Duvernay_Combined_stat = Duvernay_Combined_cln.merge(Static_log_temp, left_on='UWI',right_on='Well_ID', how='left')

# %%
Static_log_temp.head()
# Out:
#           Well_ID  Depth (ft)  Temp (degC)      Field TrueTemp_datasource_stat
# 0  42013301930000     10700.0   132.778000  Eaglebine         static_temp_logs
# 1  42041305800000      7360.0    82.777778  Eaglebine         static_temp_logs
# 2  42041311700000      7828.0   118.888889  Eaglebine         static_temp_logs
# 3  42041311980000      7954.0   105.000000  Eaglebine         static_temp_logs
# 4  42051305380000      8380.0   111.111111  Eaglebine         static_temp_logs

# %%
# Coalesce columns together with priority for true temperature measurements
Duvernay_Combined_stat['TempC_Fin'] = Duvernay_Combined_stat['Temp (degC)'].fillna(Duvernay_Combined_stat['True Temperature (oC)'])
Duvernay_Combined_stat['TrueTemp_datasource'] = Duvernay_Combined_stat['TrueTemp_datasource_stat'].fillna(Duvernay_Combined_stat['TrueTemp_datasource_syn'])

Duvernay_Combined_stat.head()
# Out:
#             Well ID  DST Start Depth (MD) (m)  DST End Depth (MD) (m)  \
# 0  100010107020W500                    1410.6                  1423.4
# 1  100010608109W500                    1686.0                  1694.0
# 2  100010904012W500                    3698.0                  3718.0
# 3  100011206021W400                     822.0                   825.0
# 4  100011506915W500                    1801.0                  1818.0
#
#    DST Bottom Hole Temp. (degC)  DST Test Date Test Type DST Misrun  \
# 0                         48.33          26025       DST          N
# 1                         34.26          33647       DST          N
# 2                        104.40          30798       LRT          N
# 3                         29.00          29543       DST          N
# 4                         64.00          30760       DST          N
#
#    DST Number Formation DSTd  Unnamed: 9  ...  diff_depth_abs  \
# 0           2      TRmontney         NaN  ...             4.0
# 1           1        Dmuskeg         NaN  ...             4.4
# 2           1        Melkton         NaN  ...             NaN
# 3           4      Dwintrbrn         NaN  ...             8.1
# 4           4       Dwabamun         NaN  ...             3.6
#
#   True Temperature (oC)  TrueTemp_datasource_syn  Well_ID  Depth (ft)  \
# 0                 60.97                synthetic      NaN         NaN
# 1                 63.98                synthetic      NaN         NaN
# 2                   NaN                synthetic      NaN         NaN
# 3                 39.07                synthetic      NaN         NaN
# 4                 69.47                synthetic      NaN         NaN
#
#   Temp (degC) Field  TrueTemp_datasource_stat  TempC_Fin TrueTemp_datasource
# 0         NaN   NaN                       NaN      60.97           synthetic
# 1         NaN   NaN                       NaN      63.98           synthetic
# 2         NaN   NaN                       NaN        NaN           synthetic
# 3         NaN   NaN                       NaN      39.07           synthetic
# 4         NaN   NaN                       NaN      69.47           synthetic
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 3.3 Plot the temp data

# %%
import matplotlib.pyplot as plt
plt.close('all')
fig, ax = plt.subplots(1, 1, figsize=(4,4))

sns.scatterplot(data=Duvernay_Combined_stat, 
                x="DST Bottom Hole Temp. (degC)",
                y="TempC_Fin",
                hue='diff_depth_abs', ax=ax)

#ax.set_xlim([30, 220])
#ax.set_ylim([30, 220])
ax.plot([0, 220], [0, 220])
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# # 4 Combine Eaglebine and Duvernay temperature datasets

# %%
Duvernay = Duvernay_Combined_stat[['UWI', 'DST Bottom Hole Temp. (degC)', 'TempC_Fin','Depth_SS(m)']]
Duvernay = Duvernay.rename(columns={'DST Bottom Hole Temp. (degC)': 'BHT', 'TempC_Fin': 'TrueTemp'})
Duvernay['Field'] = 'Duvernay'

Eaglebine = Eaglebine_Combined_stat[['UWI', 'TempC_BHT', 'TempC_Fin', 'TD (ft)']]
Eaglebine = Eaglebine.rename(columns={'TempC_BHT': 'BHT', 'TempC_Fin': 'TrueTemp'})
Eaglebine['Field'] = 'Eaglebine'

combined_temperature = pd.concat((Duvernay, Eaglebine))
combined_temperature.head()
# Out:
#                 UWI     BHT  TrueTemp  Depth_SS(m)     Field  TD (ft)
# 0  100010107020W500   48.33     60.97        716.0  Duvernay      NaN
# 1  100010608109W500   34.26     63.98       1044.4  Duvernay      NaN
# 2  100010904012W500  104.40       NaN       2424.2  Duvernay      NaN
# 3  100011206021W400   29.00     39.07        171.9  Duvernay      NaN
# 4  100011506915W500   64.00     69.47        936.4  Duvernay      NaN

# %%
# save this structured data to file
! mkdir StructuredData
combined_temperature.to_csv('StructuredData/combined_temperature.csv')

# %%
plt.close('all')
fig, ax = plt.subplots(1, 1, figsize=(4,4))

sns.scatterplot(data=combined_temperature, 
                x="BHT",
                y="TrueTemp",
                hue='Field', ax=ax)

ax.plot([0, 220], [0, 220])
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# # 5 Organize Mud-weight, formation, well header, and production data

# %% [markdown]
# This section consolidates the files provided by GTS. List of imported files and the dataframe names:
#
# - Eaglebine mud weight SPE April 21 2021.xlsx: **EB_MW**
# - Eaglebine formation tops SPE April 20 2021.xlsx: **EB_FT**
# - Eaglebine well headers SPE April 21 2021.xlsx: **EB_WH**
# - SPE Eaglebine production summary April 20 2021.xlsx: **EB_PS**
# - Duvernay formation tops SPE April 20 2021.xlsx: **DV_FT**
# - Duvernay well headers SPE April 21 2021 .xlsx: **DV_WH**
# - SPE Duvernay production summary April 20 2021.xlsx: **DV_PS**
#
# **Workflow: add the multiple entries as attributes**
#
# 1. read the excel file into a dataframe. Leave the indexing out at this stage.
# 1. for each well number (Well_Id), tag the multiple entries in a new column.
#     - New column name: 'attribute_' + the name of the column with multiple entries.
#     - Tag: name of the column with multiple entries + sequential number for multiple entries in that column
# 1. reshape the featured table to pivot on the attribute
# 1. check for dupblicates on 'Well_Id' after reshaping. If duplicates exist inspect all columns for each well. If no duplicates, it's ready for merge
#
#
# (Thanks Korang Modaressi for code)

# %%
files_to_upload = {'file': ['Eaglebine mud weight SPE April 21 2021.xlsx', 
                         'Eaglebine formation tops SPE April 20 2021.xlsx',
                         'Eaglebine well headers SPE April 21 2021.xlsx',
                         'SPE Eaglebine production summary April 20 2021.xlsx',
                         'Duvernay formation tops SPE April 20 2021.xlsx',
                         'Duvernay well headers SPE April 21 2021 .xlsx',
                         'SPE Duvernay production summary April 20 2021.xlsx'],
                  'df_name': ['EB_MW', 'EB_FT', 'EB_WH', 'EB_PS', 'DV_FT', 'DV_WH', 'DV_PS']}
files_to_upload['flat_df_name'] = [str(c) + '_flat' for c in files_to_upload['df_name']]
print(files_to_upload['flat_df_name'])
print(files_to_upload['df_name'][0][:2])
# Out:
# ['EB_MW_flat', 'EB_FT_flat', 'EB_WH_flat', 'EB_PS_flat', 'DV_FT_flat', 'DV_WH_flat', 'DV_PS_flat']
# EB

# %%
EB_MW = pd.read_excel(dir_eaglebine+"Eaglebine mud weight SPE April 21 2021.xlsx")
display(EB_MW.head())
EB_MW.columns = [c.strip() for c in EB_MW.columns.values.tolist()]
EB_MW.rename(columns = {'UWI': 'Well_Id'}, inplace = True)
# Out:
#               UWI     TD     KB  Mud Wt  MW@Depth(KB)
# 0  42013301410000  19629  327.5     9.3          4404
# 1  42013301410000  19629  327.5    11.9         12550
# 2  42013301410000  19629  327.5    11.2         12650
# 3  42013301410000  19629  327.5    11.9         12650
# 4  42013301410000  19629  327.5    11.9         14390

# %%
EB_FT = pd.read_excel(dir_eaglebine+"Eaglebine formation tops SPE April 20 2021.xlsx")
display(EB_FT.head())
EB_FT.columns = [c.strip() for c in EB_FT.columns.values.tolist()]
EB_FT.rename(columns = {'UWI': 'Well_Id'}, inplace = True)
# Out:
#               UWI  ...  19_Cotton_Valley_MD_ft
# 0  42013301410000  ...                     0.0
# 1  42013301930000  ...                     0.0
# 2  42013302760000  ...                     0.0
# 3  42013305480000  ...                     0.0
# 4  42013310190000  ...                     0.0
#
# [5 rows x 29 columns]

# %%
EB_WH = pd.read_excel(dir_eaglebine+"Eaglebine well headers SPE April 21 2021.xlsx")
display(EB_WH.head())
EB_WH.rename(columns = {'displayapi': 'Well_Id'}, inplace = True)
# Out:
#       td  Elevation  ... BottomLatitude_NAD27  BottomLongitude_NAD27
# 0  19635     338.68  ...            28.689839             -98.469523
# 1  10775     384.59  ...            28.779784             -98.208109
# 2   6175     442.00  ...            28.994561             -98.422475
# 3   8198     392.00  ...            28.963144             -98.295672
# 4  11000     493.23  ...            28.817682             -98.155187
#
# [5 rows x 16 columns]

# %%
EB_PS = pd.read_excel(dir_eaglebine+"SPE Eaglebine production summary April 20 2021.xlsx")
display(EB_PS.head())
EB_PS.columns = [c.strip() for c in EB_PS.columns.values.tolist()]
EB_PS.rename(columns = {'API': 'Well_Id'}, inplace = True)
# Out:
#            API     ...  Gas Injection Cum (mcf)
# 0  42013301410000  ...                         NaN
# 1  42013301930000  ...                         NaN
# 2  42013302760000  ...                         NaN
# 3  42013305480000  ...                         NaN
# 4  42013310190000  ...                         NaN
#
# [5 rows x 23 columns]

# %%
DV_FT = pd.read_excel(dir_duvernay+"Duvernay formation tops SPE April 20 2021.xlsx")
display(DV_FT.head())
DV_FT.columns = [c.strip() for c in DV_FT.columns.values.tolist()]
DV_FT.rename(columns = {'UWI': 'Well_Id'}, inplace = True)
# Out:
#                 UWI  ...  17_Precambrian Basement (Surbiton)[SSTVD] (m)
# 0  100010107020W500  ...                                            NaN
# 1  100010608109W500  ...                                        -1078.4
# 2  100010904012W500  ...                                            NaN
# 3  100011206021W400  ...                                            NaN
# 4  100011506915W500  ...                                            NaN
#
# [5 rows x 21 columns]

# %%
DV_WH = pd.read_excel(dir_duvernay+"Duvernay well headers SPE April 21 2021 .xlsx")
display(DV_WH.head())
DV_WH.columns = [c.strip() for c in DV_WH.columns.values.tolist()]
DV_WH.rename(columns = {'UWI': 'Well_Id'}, inplace = True)
# Out:
#                UWI   ...  BottomLongitude_NAD27
# 0  100072507623W500  ...            -117.423800
# 1  100062007823W500  ...            -117.537674
# 2  100052107723W500  ...            -117.516168
# 3  100061307518W500  ...            -116.653606
# 4  100070907618W500  ...            -116.726243
#
# [5 rows x 12 columns]

# %%
DV_PS = pd.read_excel(dir_duvernay+"SPE Duvernay production summary April 20 2021.xlsx")
display(DV_PS.head())
DV_PS.columns = [c.strip() for c in DV_PS.columns.values.tolist()]
DV_PS.rename(columns = {'API': 'Well_Id'}, inplace = True)
# Out:
#              API     ...  Yield Total Average
# 0  100010107020W500  ...                     NaN
# 1  100010608109W500  ...                1256.918
# 2  100010904012W500  ...                     NaN
# 3  100011206021W400  ...                     NaN
# 4  100011506915W500  ...                     NaN
#
# [5 rows x 24 columns]

# %%
# Loop thorugh each well (Well_Id), convert each column into ndarray with Well_Id as key
# Useful functions definitions
''' list the unique well identifiers (Well_Id) in the table and the number of rows for each. The new dataframe will be used to populate the columns of the wide table'''
def wells_and_attributes(df):
    well_data = df
    columns = well_data.columns
    well_data_count = well_data['Well_Id'].value_counts()
    wells = well_data_count.index
    return well_data, wells, columns

''' 
The 'entry_to_attr' function collects the unique Well_Id and pivots entries under each Well_Id into attributes. 
The loop check for each unique well number in well_data_count, loops through columns and pivots the values in each column into a dataframe.
The name of the current column is used as prefix with an underscore "columnname_" joined with suffix as the index (from 0) of the entries for each well. 
The extracted variables are turned into dataframe and is concatenated with the existing dataframe from previous loop. 
'''
def entry_to_attr(df):
    well_data_flat = pd.DataFrame() #dataframe for storing well records after change to wide format
    well_data, wells, columns = wells_and_attributes(df) #read 'wells_and_attributes' function description
    for well in wells:
        well_data_intermediate_flat = pd.DataFrame() #temporary dataframe to store pivoted entries to new attributes for each original column
        well_data_filtered = well_data[well_data['Well_Id'] == well] #filterd for 'well' to start pivoting to new attributes
        #print(well_data_filtered)
        for column in columns: #pivots columns for each well into new attributes
            if column == 'Well_Id': #ignores the Well_Id and flattens othe columns
                continue
            else:
                att_vars = np.array(well_data_filtered[column]) #array containing entries in 'column' for 'well'
                att_count = len(att_vars) #number of entries in the array used for naming the new columns
                att_names = [column+"_"+str(x) for x in range(att_count)] #new column name with number of entries (att_count array's length) as suffix
                well_data_intermediate = pd.DataFrame(att_vars).T #intermediate flat table to be merged with the temporary dataframe
                well_data_intermediate.columns = att_names
                index = pd.Index([well], name = 'Well_Id')
                well_data_intermediate.index = index
                well_data_intermediate_flat = pd.concat([well_data_intermediate_flat, well_data_intermediate], axis = 1)
        well_data_flat = pd.concat([well_data_flat, well_data_intermediate_flat])
    return well_data_flat

# %%
'''
In this loop the entry_to_attr funciton is looped for the dataframes:
    'EB_MW', 'EB_FT', 'EB_WH', 'EB_PS', 'DV_FT', 'DV_WH', 'DV_PS'
The resulting wide-format dataframe is stored in a new datafram. 
The wide-format dataframes are concatenated into one dataframe with Well_ID as index
'''
dataframes = [EB_MW, EB_FT, EB_WH, EB_PS, DV_FT, DV_WH, DV_PS]
consolidated_well_data = pd.DataFrame()
cols = []
rows = []
# consolidated_well_data = pd.concat([consolidated_well_data, dataframes[0], dataframes[1], dataframes[2]])
for i in range(len(dataframes)): #
    well_data_flat = entry_to_attr(dataframes[i])
    well_data_flat['Basin'] = files_to_upload['df_name'][i][:2]
    well_data_flat.reset_index(inplace = True)
    well_data_flat.to_excel(str(str(files_to_upload['flat_df_name'][i]) + '.' + 'xlsx'))
    print(well_data_flat.shape)
    well_data_flat.set_index(['Well_Id', 'Basin'], inplace = True)
    consolidated_well_data = pd.concat([consolidated_well_data, well_data_flat], axis = 1)
consolidated_well_data.shape
display(consolidated_well_data.head())
print('the consolidated_well_data has {} rows and {} columns'.format(consolidated_well_data.shape[0], consolidated_well_data.shape[1]))
# Out:
# (316, 54)
# (324, 30)
# (324, 17)
# (308, 90)
# (512, 22)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/multi.py:3369: RuntimeWarning: The values in the array are unorderable. Pass `sort=False` to suppress this warning.
#   uniq_tuples = lib.fast_unique_multiple([self._values, other._values], sort=sort)
# (512, 13)
# (512, 25)
#                          TD_0  ...  Yield Total Average_0
# Well_Id        Basin           ...
# 42013301410000 EB     19629.0  ...                    NaN
# 42013301930000 EB     10775.0  ...                    NaN
# 42013302760000 EB      6168.0  ...                    NaN
# 42013305480000 EB      8198.0  ...                    NaN
# 42013310190000 EB     11000.0  ...                    NaN
#
# [5 rows x 237 columns]
# the consolidated_well_data has 836 rows and 237 columns

# %%
consolidated_well_data_no_index = consolidated_well_data.reset_index()
consolidated_well_data.to_csv('StructuredData/consolidated_well_data.csv')
consolidated_well_data.to_excel('StructuredData/consolidated_well_data.xlsx')

# %% [markdown]
# # 6 Organize LAS file

# %%
### Thanks to Pushpesh Sharma for writing this section

# %%
import os
# !pip install lasio
import lasio
# Out:
# Collecting lasio
#   Downloading https://files.pythonhosted.org/packages/a3/f6/5e9fd182a0ab82bc76d2d1a3e8102db48325fc4dece54fb7848ca87272eb/lasio-0.29-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lasio) (1.19.5)
# Installing collected packages: lasio
# Successfully installed lasio-0.29

# %%
#Load all files at once into las and las_df to save time
folder='clean_las_files/Clean_LAS/'
all_files = os.listdir(folder)
n_files = len(all_files)

bad_files = []

las = {}
las_df = {}
mnemonics ={}
i=0
for filename in tqdm(os.listdir(folder)):
    i=i+1
    if filename.endswith(".LAS"):
        las[filename] = lasio.read(folder+'/'+filename)
        las_df[filename] = las[filename].df()
        mnemonics[filename] = las_df[filename].columns
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1498.0), HTML(value='')))

# %%
#find out which well curves/logs are in each las file
listDF = []
for filename in tqdm(all_files):
    df = pd.DataFrame(columns = list(mnemonics[filename]), data = np.ones((1,len(mnemonics[filename]))))
    df['well_name']=filename
    listDF.append(df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1498.0), HTML(value='')))

# %%
log_table=pd.concat(listDF)

# %%
# Here we can see which logs are in each well
log_table.head()
# Out:
#    CALDED  CALSED  CALWS  CONDWS  ...  TENS1ED  TENR_1  CALSD  DCORR
# 0     1.0     1.0    1.0     1.0  ...      NaN     NaN    NaN    NaN
# 0     NaN     NaN    NaN     NaN  ...      NaN     NaN    NaN    NaN
# 0     NaN     NaN    1.0     1.0  ...      NaN     NaN    NaN    NaN
# 0     NaN     NaN    1.0     1.0  ...      NaN     NaN    NaN    NaN
# 0     1.0     1.0    1.0     1.0  ...      NaN     NaN    NaN    NaN
#
# [5 rows x 794 columns]

# %%
# see what are the most common log types
sumT = log_table.drop(columns=['well_name']).sum()
sumT.sort_values(ascending=False)
# Out:
# SPR        797.0
# GRWS       660.0
# DRESWS     657.0
# CONDWS     656.0
# CALWS      650.0
#            ...
# TRATED       1.0
# TAU_1        1.0
# TAU_2        1.0
# GRR_1ED      1.0
# GDEN         1.0
# Length: 793, dtype: float64

# %%
# make a table of the log types available per well
for filename in all_files:
    las_df[filename] = las_df[filename].rename_axis('DEPT').reset_index()

# %%
# we can extract the gamma ray values [GRWS] at 
# regular intervals to add to the dataset (every 300 ft)
WellLog = 'GRWS'

select_depth = list(np.arange(300, 30300, 300))
new_las_df = {}
extracted_df = {}
j = 0
fncnt = 0
for filename in tqdm(all_files):
    fncnt = fncnt+1

    las_df[filename] = las_df[filename].sort_values(by='DEPT')
    p = las_df[filename]
    new_las_df[filename] = p[p['DEPT'].isin(select_depth)]
    if(WellLog not in list(new_las_df[filename].columns)):
      continue
    q = new_las_df[filename][WellLog]
    Depth = new_las_df[filename]['DEPT']
    
    concat_list = list()
    column_name = list()
    for i in range(0,q.shape[0]):
        concat_list.append(q.iloc[i])
        column_name.append(str(Depth.iloc[i])+'_'+WellLog)
        
    concat_array = np.array(concat_list)
    concat_array = np.reshape(concat_array,(1,len(concat_list)))
    df = pd.DataFrame(concat_array, columns=column_name)
    df['WellName'] = filename[2:16]
    if filename[-5] == 'W':
        df['LogType'] = 'Cleaned'
    else:
        df['LogType'] = 'Raw'
    extracted_df[j] = df
    j = j+1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1498.0), HTML(value='')))

# %%
LargeDF = pd.concat(extracted_df)
LargeDF.to_csv('StructuredData/LogData.csv')

# %% [markdown]
# # 7 Combine all data sources together

# %%
TemperatureData = pd.read_csv('StructuredData/combined_temperature.csv')
HeaderData = pd.read_csv('StructuredData/consolidated_well_data.csv')
LogData = pd.read_csv('StructuredData/LogData.csv')

Combined1 = TemperatureData.merge(HeaderData, how='left', left_on='UWI', right_on='Well_Id')
LogData['WellName']=LogData['WellName'].astype('str')
Combined1['UWI']=Combined1['UWI'].astype('str')
LogData = LogData.drop_duplicates(['WellName'])
Combined2 = Combined1.merge(LogData, how='left', left_on='UWI', right_on='WellName')
Combined2.head()
# Out:
#    Unnamed: 0_x               UWI  ...  23700.0_GRWS  24000.0_GRWS
# 0             0  100010107020W500  ...           NaN           NaN
# 1             1  100010608109W500  ...           NaN           NaN
# 2             2  100010904012W500  ...           NaN           NaN
# 3             3  100011206021W400  ...           NaN           NaN
# 4             4  100011506915W500  ...           NaN           NaN
#
# [5 rows x 330 columns]

# %%
print('There are ' + str(len(Combined2)) + ' rows and ' + str(len(Combined2.columns) ) + ' columns in the dataframe')
# Out:
# There are 836 rows and 330 columns in the dataframe

# %% [markdown]
# # 8 Separate into the training and validation/testing sets

# %%
set_split = pd.read_csv('Data for Datathon/set_assign.csv')
set_split.head()
# Out:
#                 UWI                 Set
# 0    42021301990000  Validation_Testing
# 1  100102606420W500  Validation_Testing
# 2  100141705519W500  Validation_Testing
# 3  100141503621W400  Validation_Testing
# 4  100043406718W500  Validation_Testing

# %%
Combined3 = Combined2.merge(set_split, on='UWI', how='left')

# %%
filterTraining = Combined3['Set']=='Training'
Combined3[filterTraining].to_csv('training.csv', index=False)

filterTesting = Combined3['Set']=='Validation_Testing'
Combined3[filterTesting].to_csv('val_data_no_label.csv', index=False)

# %% [markdown]
# # 9 Practice submission!!
# ### Make sure your final submission should have two columns which are named "TrueTemp" and "UWI". The final file must be named "predictions.csv" and it should be zipped as "predictions.zip".

# %%
train = pd.read_csv('training.csv')

# %%
train.head()
# Out:
#    Unnamed: 0_x               UWI    BHT  ...  23700.0_GRWS  24000.0_GRWS       Set
# 0             0  100010107020W500  48.33  ...           NaN           NaN  Training
# 1             1  100010608109W500  34.26  ...           NaN           NaN  Training
# 2             3  100011206021W400  29.00  ...           NaN           NaN  Training
# 3             4  100011506915W500  64.00  ...           NaN           NaN  Training
# 4             5  100011804403W500  68.00  ...           NaN           NaN  Training
#
# [5 rows x 331 columns]

# %% [markdown]
# ## 9.1 create basic linear regression model

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(train['BHT'].values.reshape(-1, 1),
                             train['TrueTemp'].values.reshape(-1, 1))
x = np.arange(200)
y_hat = reg.predict(x.reshape(-1, 1))

# %%
fig, ax = plt.subplots(1, 1, figsize=(4,4))

sns.scatterplot(data=train, x="BHT", y="TrueTemp", hue='Field', ax=ax)

ax.set_xlim([30, 220])
ax.set_ylim([30, 220])
ax.plot([0, 220], [0, 220], label='1-1', c='k')

ax.plot(x, y_hat, label='linear pred', c='r')

plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# ## 9.2 Use the linear regression model to predict on the validation set

# %%
test_data = pd.read_csv('val_data_no_label.csv')
test_data.head()
# Out:
#    Unnamed: 0_x               UWI  ...  24000.0_GRWS                 Set
# 0             8  100012404516W502  ...           NaN  Validation_Testing
# 1            10  100012805703W500  ...           NaN  Validation_Testing
# 2            16  100020206419W500  ...           NaN  Validation_Testing
# 3            19  100020605904W500  ...           NaN  Validation_Testing
# 4            20  100020606216W500  ...           NaN  Validation_Testing
#
# [5 rows x 331 columns]

# %%
prediction = reg.predict(test_data['BHT'].values.reshape(-1, 1))

# %%
test_data['TrueTemp']=prediction

# %%
test_data[['UWI','TrueTemp']].to_csv('predictions.csv')

# %%
import zipfile
zipfile.ZipFile('predictions.zip', mode='w').write("predictions.csv")
